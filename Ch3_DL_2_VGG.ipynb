# %% [markdown]
# # Chapter 3. Deep learning Practice
#  CIFAR-10 Classification with VGG
#
# 참고한 사이트: https://github.com/heartcored98/Standalone-DeepLearning/blob/master/

# %%
# !mkdir results
# Out:
# ���� ���͸� �Ǵ� ���� results��(��) �̹� �ֽ��ϴ�.

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import time
from copy import deepcopy # Add Deepcopy for args
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import argparse
parser = argparse.ArgumentParser()
args = parser.parse_args("")

args.exp_name = "exp1_lr"
args.act = 'relu'
args.l2 = 'l2'
args.optim = 'Adam'
args.lr = 0.0015
args.epoch = 50

args.train_batch_size = 512
args.test_batch_size = 1024

print(args)
# Out:
# Namespace(exp_name='exp1_lr', act='relu', l2='l2', optim='Adam', lr=0.0015, epoch=50, train_batch_size=512, test_batch_size=1024)

# %% [markdown]
# # Data Preparation
#
# - 기존 CIFAR-10 데이터 저장 코드에서 10을 100으로 바꿔주기만 하면 CIFAR-100 dataset을 사용할 수 있음.
# - train, valid, test set을 각각 전처리하여 partition dictionary에 저장

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainset, valset = torch.utils.data.random_split(trainset, [40000, 10000])
testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
partition = {'train': trainset, 'val':valset, 'test':testset} # dataset을 나눠놓음
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # Model Architecture
#
# VGG11모델 예시
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### VGG 모델

# %%
cfg = {
    'VGG11': [64, 'M', 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'VGG13': [64, 64, 'M', 128, 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'VGG16': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M'],
    'VGG19': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 256, 'M', 512, 512, 512, 512, 'M', 512, 512, 512, 512, 'M']
}

# %%
class CNN(nn.Module):

    def __init__(self, model_code, in_channels):
        super(CNN, self).__init__()

        self.layers = self._make_layers(model_code, in_channels)
        self.classifier = nn.Sequential(nn.Linear(512, 4096),
                                        nn.ReLU(),
                                        nn.Linear(4096, 10))

    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

    def _make_layers(self, model_code, in_channels):
        layers = nn.ModuleList()
        for x in cfg[model_code]:
            if x != 'M':
                layers.append(nn.Conv2d(in_channels=in_channels,
                                        out_channels=x,
                                        kernel_size=3,
                                        stride=1,
                                        padding=1))
                layers.append(nn.ReLU())
                in_channels = x
            else:
                layers.append(nn.MaxPool2d(kernel_size=2,
                                           stride=2))
        return layers

# %%
def dimesion_check(vgg_name):
    model = CNN(vgg_name, 3)
    x = torch.randn(2, 3, 32, 32)
    y = model(x)
    print(y.shape)

# %%
vgg_name = 'VGG11'
dimesion_check(vgg_name)
# Out:
# torch.Size([2, 10])

# %%
def train(model, partition, optimizer, criterion, args):
    trainloader = torch.utils.data.DataLoader(partition['train'],
                                              batch_size=args.train_batch_size,
                                              shuffle=True, num_workers=2)
    model.train()

    correct = 0
    total = 0
    train_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        optimizer.zero_grad()

        # get the inputs
        inputs, labels = data
        inputs = inputs.cuda()
        labels = labels.cuda()
        outputs = model(inputs)

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = train_loss / len(trainloader)
    train_acc = 100 * correct / total
    return model, train_loss, train_acc

# %%
def validate(model, partition, criterion, args):
    valloader = torch.utils.data.DataLoader(partition['val'],
                                            batch_size=args.test_batch_size,
                                            shuffle=False, num_workers=2)
    model.eval()

    correct = 0
    total = 0
    val_loss = 0
    with torch.no_grad():
        for data in valloader:
            images, labels = data
            images = images.cuda()
            labels = labels.cuda()
            outputs = model(images)

            loss = criterion(outputs, labels)

            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        val_loss = val_loss / len(valloader)
        val_acc = 100 * correct / total
    return val_loss, val_acc

# %%
def test(model, partition, criterion, args):
    testloader = torch.utils.data.DataLoader(partition['test'],
                                             batch_size=args.test_batch_size,
                                             shuffle=False, num_workers=2)
    model.eval()

    correct = 0
    total = 0
    te_loss=0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images = images.cuda()
            labels = labels.cuda()

            outputs = model(images)
            loss = criterion(outputs, labels)

            te_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        te_loss = te_loss / len(testloader)
        test_acc = 100 * correct / total
    return te_loss, test_acc

# %% [markdown]
# - 실험시 훈련, 검증, 평가를 반복 수행하기 떄문에 사용자 함수화.
# - 실험도 여러 조건에서 수행하므로 함수화 진행
#
# - args: 실험변수 저장
# - result: 실험변수 저장 dictionary

# %%
def experiment(partition,vgg_name, args):

    model = CNN(vgg_name, 3)
    model.cuda()

    criterion = nn.CrossEntropyLoss()
    if args.optim == 'SGD':
        optimizer = optim.SGD(model.parameters(), lr=args.lr, weight_decay=args.l2)
    elif args.optim == 'RMSprop':
        optimizer = optim.RMSprop(model.parameters(), lr=args.lr, weight_decay=args.l2)
    elif args.optim == 'Adam':
        optimizer = optim.Adam(model.parameters(), lr=args.lr, weight_decay=args.l2)
    else:
        raise ValueError('In-valid optimizer choice')

    train_losses = []
    val_losses = []
    te_losses = []
    train_accs = []
    val_accs = []
    te_accs = []

    for epoch in range(args.epoch):  # loop over the dataset multiple times
        ts = time.time()
        model, train_loss, train_acc = train(model, partition, optimizer, criterion, args)
        val_loss, val_acc = validate(model, partition, criterion, args)
        te = time.time()
        te_loss, te_acc = test(model,partition,criterion, args)

        train_losses.append(train_loss)
        val_losses.append(val_loss)
        te_losses.append(te_loss)

        train_accs.append(train_acc)
        val_accs.append(val_acc)
        te_accs.append(te_acc)

        print('Epoch {}, Acc(train/val/test): {:2.2f}/{:2.2f}/{:2.2f}, Loss(train/val/test) {:2.2f}/{:2.2f}/{:2.2f}. Took {:2.2f} sec'.format(epoch, train_acc, val_acc, te_acc, train_loss, val_loss,te_loss, te-ts))


    result = {}

    result['train_losses'] = train_losses
    result['val_losses'] = val_losses
    result['te_losses'] = te_losses

    result['train_loss'] = train_loss # 마지막 epoch 결과
    result['val_loss'] = val_loss
    result['test_loss'] = te_loss

    result['train_accs'] = train_accs
    result['val_accs'] = val_accs
    result['test_accs'] = te_accs


    result['train_acc'] = train_acc # 마지막 epoch 결과
    result['val_acc'] = val_acc
    result['test_acc'] = te_acc

    return vars(args), result

# %% [markdown]
# ### Management experiment result

# %%
import hashlib
import json
from os import listdir
from os.path import isfile, join
import pandas as pd

def save_exp_result(setting, result, df_new):
    exp_name = setting['exp_name']

    del df_new['epoch']
    del df_new['test_batch_size']

    filename_df = './results/{}.csv'.format(exp_name)

    df_new.to_csv(filename_df)


def load_exp_result(exp_name):
    dir_path = './results'

    filenames = [f for f in listdir(dir_path) if isfile(join(dir_path, f)) if '.csv' in f]

    list_result = []
    for filename in filenames:
        if exp_name in filename:
            df_new = pd.read_csv(join(dir_path, filename))

    return df_new

# %% [markdown]
# ### Visualization

# %%
def plot_acc(var1, var2, df):

    fig, ax = plt.subplots(2, 3)
    fig.set_size_inches(15, 8)

    grouped = df.groupby([var1, var2])
    grouped['train_acc'].mean().plot(kind='bar',  ax=ax[0,0])
    grouped['val_acc'].mean().plot(kind='bar',  ax=ax[0,1])
    grouped['test_acc'].mean().plot(kind='bar',  ax=ax[0,2])
    grouped['train_loss'].mean().plot(kind='bar',  ax=ax[1,0])
    grouped['val_loss'].mean().plot(kind='bar',  ax=ax[1,1])
    grouped['test_loss'].mean().plot(kind='bar',  ax=ax[1,2])

    ax[0,0].set_title('Train Accuracy')
    ax[0,1].set_title('Validation Accuracy')
    ax[0,2].set_title('Test Accuracy')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Experiment

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# ====== Random Seed Initialization ====== #
seed = 123
np.random.seed(seed)
torch.manual_seed(seed)

# ====== Experiment Variable ====== #
name_var1 = 'l2'
name_var2 = 'optim'
list_var1 = [0.0001,0.001]
list_var2 = ['Adam','RMSprop']
df_new = pd.DataFrame()
for var1 in list_var1:
    for var2 in list_var2:
        args.l2 = var2
        args.optim = var1

        setattr(args, name_var1, var1)
        setattr(args, name_var2, var2)
        print(args)

        setting, result = experiment(partition,vgg_name, args)
        dict_result = result|setting

        df_new = pd.concat([df_new, pd.DataFrame([dict_result])])

save_exp_result(setting, result,df_new) # 실험결과 json으로 저장
# Out:
# Namespace(exp_name='exp1_lr', act='relu', l2=0.0001, optim='Adam', lr=0.0015, epoch=50, train_batch_size=512, test_batch_size=1024)
# Epoch 0, Acc(train/val/test): 11.13/9.07/8.54, Loss(train/val/test) 2.30/2.32/2.32. Took 12.19 sec
# Epoch 1, Acc(train/val/test): 19.28/23.87/23.73, Loss(train/val/test) 2.00/1.87/1.87. Took 12.00 sec
# Epoch 2, Acc(train/val/test): 27.64/30.52/30.23, Loss(train/val/test) 1.81/1.76/1.75. Took 12.20 sec
# Epoch 3, Acc(train/val/test): 35.33/39.80/39.92, Loss(train/val/test) 1.66/1.58/1.56. Took 11.78 sec
# Epoch 4, Acc(train/val/test): 41.77/46.84/46.52, Loss(train/val/test) 1.52/1.44/1.44. Took 11.73 sec
# Epoch 5, Acc(train/val/test): 48.77/49.48/49.96, Loss(train/val/test) 1.37/1.36/1.34. Took 12.34 sec
# Epoch 6, Acc(train/val/test): 53.22/54.15/54.01, Loss(train/val/test) 1.27/1.25/1.25. Took 12.17 sec
# Epoch 7, Acc(train/val/test): 57.43/55.65/55.39, Loss(train/val/test) 1.17/1.24/1.25. Took 12.17 sec
# Epoch 8, Acc(train/val/test): 60.27/59.63/59.09, Loss(train/val/test) 1.09/1.13/1.13. Took 12.08 sec
# Epoch 9, Acc(train/val/test): 63.35/61.89/61.56, Loss(train/val/test) 1.02/1.08/1.09. Took 11.95 sec
# Epoch 10, Acc(train/val/test): 65.64/59.24/58.22, Loss(train/val/test) 0.96/1.18/1.22. Took 12.02 sec
# Epoch 11, Acc(train/val/test): 68.01/64.65/63.97, Loss(train/val/test) 0.90/1.02/1.03. Took 11.89 sec
# Epoch 12, Acc(train/val/test): 70.44/67.72/67.29, Loss(train/val/test) 0.83/0.92/0.94. Took 11.93 sec
# Epoch 13, Acc(train/val/test): 72.11/67.99/67.26, Loss(train/val/test) 0.78/0.92/0.94. Took 11.82 sec
# Epoch 14, Acc(train/val/test): 74.24/67.55/67.85, Loss(train/val/test) 0.73/0.94/0.94. Took 11.87 sec
# Epoch 15, Acc(train/val/test): 76.06/66.14/66.10, Loss(train/val/test) 0.68/1.01/1.01. Took 12.01 sec
# Epoch 16, Acc(train/val/test): 77.08/69.23/68.95, Loss(train/val/test) 0.65/0.96/0.95. Took 11.96 sec
# Epoch 17, Acc(train/val/test): 79.08/69.31/68.90, Loss(train/val/test) 0.60/0.97/0.97. Took 12.09 sec
# Epoch 18, Acc(train/val/test): 80.66/71.11/70.67, Loss(train/val/test) 0.55/0.88/0.90. Took 11.95 sec
# Epoch 19, Acc(train/val/test): 81.97/70.34/69.71, Loss(train/val/test) 0.51/0.96/0.97. Took 12.00 sec
# Epoch 20, Acc(train/val/test): 83.28/67.39/66.53, Loss(train/val/test) 0.48/1.10/1.09. Took 11.79 sec
# Epoch 21, Acc(train/val/test): 84.45/71.11/70.06, Loss(train/val/test) 0.44/1.00/1.00. Took 11.96 sec
# Epoch 22, Acc(train/val/test): 86.49/69.79/69.01, Loss(train/val/test) 0.39/1.04/1.05. Took 11.94 sec
# Epoch 23, Acc(train/val/test): 87.82/71.25/70.23, Loss(train/val/test) 0.35/1.05/1.08. Took 11.70 sec
# Epoch 24, Acc(train/val/test): 89.19/69.91/69.71, Loss(train/val/test) 0.31/1.13/1.14. Took 11.96 sec
# Epoch 25, Acc(train/val/test): 89.59/70.37/69.83, Loss(train/val/test) 0.30/1.13/1.14. Took 11.87 sec
# Epoch 26, Acc(train/val/test): 90.94/69.30/68.98, Loss(train/val/test) 0.26/1.26/1.27. Took 11.98 sec
# Epoch 27, Acc(train/val/test): 92.02/68.79/67.66, Loss(train/val/test) 0.23/1.35/1.40. Took 11.93 sec
# Epoch 28, Acc(train/val/test): 91.38/68.55/68.14, Loss(train/val/test) 0.25/1.44/1.46. Took 11.97 sec
# Epoch 29, Acc(train/val/test): 93.69/70.44/69.59, Loss(train/val/test) 0.19/1.34/1.40. Took 12.16 sec
# Epoch 30, Acc(train/val/test): 93.65/69.44/68.46, Loss(train/val/test) 0.18/1.39/1.42. Took 11.87 sec
# Epoch 31, Acc(train/val/test): 93.48/70.43/70.07, Loss(train/val/test) 0.19/1.33/1.34. Took 12.01 sec
# Epoch 32, Acc(train/val/test): 94.70/70.32/69.99, Loss(train/val/test) 0.15/1.52/1.54. Took 11.90 sec
# Epoch 33, Acc(train/val/test): 95.41/69.68/68.56, Loss(train/val/test) 0.14/1.54/1.59. Took 11.87 sec
# Epoch 34, Acc(train/val/test): 95.35/70.82/70.10, Loss(train/val/test) 0.13/1.57/1.61. Took 12.14 sec
# Epoch 35, Acc(train/val/test): 95.72/70.59/69.64, Loss(train/val/test) 0.12/1.59/1.62. Took 12.00 sec
# Epoch 36, Acc(train/val/test): 96.45/71.25/69.68, Loss(train/val/test) 0.10/1.67/1.70. Took 12.12 sec
# Epoch 37, Acc(train/val/test): 97.14/68.42/67.18, Loss(train/val/test) 0.09/1.79/1.83. Took 11.93 sec
# Epoch 38, Acc(train/val/test): 94.98/69.53/68.37, Loss(train/val/test) 0.15/1.78/1.82. Took 11.99 sec
# Epoch 39, Acc(train/val/test): 96.10/70.93/69.95, Loss(train/val/test) 0.11/1.65/1.67. Took 11.90 sec
# Epoch 40, Acc(train/val/test): 96.89/71.09/69.94, Loss(train/val/test) 0.09/1.69/1.74. Took 12.01 sec
# Epoch 41, Acc(train/val/test): 97.56/71.36/70.26, Loss(train/val/test) 0.07/1.81/1.85. Took 12.17 sec
# Epoch 42, Acc(train/val/test): 98.08/71.47/70.12, Loss(train/val/test) 0.06/1.93/1.97. Took 11.98 sec
# Epoch 43, Acc(train/val/test): 96.68/71.43/69.94, Loss(train/val/test) 0.10/1.66/1.71. Took 11.97 sec
# Epoch 44, Acc(train/val/test): 98.29/70.17/68.62, Loss(train/val/test) 0.05/1.87/1.94. Took 12.13 sec
# Epoch 45, Acc(train/val/test): 97.42/71.05/69.63, Loss(train/val/test) 0.08/1.67/1.75. Took 12.05 sec
# Epoch 46, Acc(train/val/test): 98.04/70.87/69.49, Loss(train/val/test) 0.06/1.78/1.87. Took 11.98 sec
# Epoch 47, Acc(train/val/test): 97.51/70.66/69.75, Loss(train/val/test) 0.07/1.91/1.94. Took 11.77 sec
# Epoch 48, Acc(train/val/test): 97.52/71.01/69.09, Loss(train/val/test) 0.07/1.80/1.87. Took 11.84 sec
# Epoch 49, Acc(train/val/test): 97.33/70.60/69.77, Loss(train/val/test) 0.08/1.74/1.80. Took 11.96 sec
# Namespace(exp_name='exp1_lr', act='relu', l2=0.0001, optim='RMSprop', lr=0.0015, epoch=50, train_batch_size=512, test_batch_size=1024)
# Epoch 0, Acc(train/val/test): 10.01/10.16/10.00, Loss(train/val/test) 13.96/2.34/2.34. Took 11.67 sec
# Epoch 1, Acc(train/val/test): 9.71/9.89/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.95 sec
# Epoch 2, Acc(train/val/test): 9.59/10.16/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.97 sec
# Epoch 3, Acc(train/val/test): 9.83/10.08/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.82 sec
# Epoch 4, Acc(train/val/test): 9.80/10.16/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.86 sec
# Epoch 5, Acc(train/val/test): 9.87/10.16/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.96 sec
# Epoch 6, Acc(train/val/test): 9.78/9.98/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.84 sec
# Epoch 7, Acc(train/val/test): 9.75/10.06/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.79 sec
# Epoch 8, Acc(train/val/test): 9.95/9.98/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.96 sec
# Epoch 9, Acc(train/val/test): 9.61/9.98/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.85 sec
# Epoch 10, Acc(train/val/test): 9.87/9.89/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 12.03 sec
# Epoch 11, Acc(train/val/test): 9.79/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.75 sec
# Epoch 12, Acc(train/val/test): 9.71/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.93 sec
# Epoch 13, Acc(train/val/test): 9.72/9.92/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 12.09 sec
# Epoch 14, Acc(train/val/test): 9.84/9.89/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.97 sec
# Epoch 15, Acc(train/val/test): 9.79/9.92/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.85 sec
# Epoch 16, Acc(train/val/test): 9.94/10.06/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 12.05 sec
# Epoch 17, Acc(train/val/test): 9.79/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.93 sec
# Epoch 18, Acc(train/val/test): 9.83/10.06/10.00, Loss(train/val/test) 2.31/2.30/2.30. Took 11.77 sec
# Epoch 19, Acc(train/val/test): 9.94/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.93 sec
# Epoch 20, Acc(train/val/test): 9.87/9.89/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.87 sec
# Epoch 21, Acc(train/val/test): 9.79/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.81 sec
# Epoch 22, Acc(train/val/test): 9.97/10.16/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.70 sec
# Epoch 23, Acc(train/val/test): 9.71/10.08/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.88 sec
# Epoch 24, Acc(train/val/test): 9.92/9.92/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.77 sec
# Epoch 25, Acc(train/val/test): 9.64/9.69/10.00, Loss(train/val/test) 2.39/2.30/2.30. Took 11.68 sec
# Epoch 26, Acc(train/val/test): 9.79/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.81 sec
# Epoch 27, Acc(train/val/test): 9.81/9.92/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.70 sec
# Epoch 28, Acc(train/val/test): 10.06/10.16/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.69 sec
# Epoch 29, Acc(train/val/test): 10.06/10.08/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.82 sec
# Epoch 30, Acc(train/val/test): 9.68/10.08/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.74 sec
# Epoch 31, Acc(train/val/test): 10.04/9.98/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.81 sec
# Epoch 32, Acc(train/val/test): 10.02/9.98/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.68 sec
# Epoch 33, Acc(train/val/test): 9.71/10.06/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.70 sec
# Epoch 34, Acc(train/val/test): 9.76/10.06/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.80 sec
# Epoch 35, Acc(train/val/test): 9.82/9.89/10.00, Loss(train/val/test) 5.91/2.30/2.30. Took 11.88 sec
# Epoch 36, Acc(train/val/test): 10.11/10.16/10.00, Loss(train/val/test) 2.40/2.70/2.70. Took 11.79 sec
# Epoch 37, Acc(train/val/test): 15.60/18.66/19.18, Loss(train/val/test) 2.20/2.11/2.10. Took 11.71 sec
# Epoch 38, Acc(train/val/test): 17.45/16.93/17.96, Loss(train/val/test) 2.13/2.14/2.12. Took 11.70 sec
# Epoch 39, Acc(train/val/test): 18.32/15.63/15.61, Loss(train/val/test) 2.08/2.11/2.12. Took 11.78 sec
# Epoch 40, Acc(train/val/test): 19.61/10.16/10.00, Loss(train/val/test) 2.29/2.30/2.30. Took 11.68 sec
# Epoch 41, Acc(train/val/test): 15.60/21.36/22.32, Loss(train/val/test) 2.31/2.04/2.02. Took 11.89 sec
# Epoch 42, Acc(train/val/test): 21.21/22.32/22.14, Loss(train/val/test) 2.03/1.95/1.96. Took 11.82 sec
# Epoch 43, Acc(train/val/test): 24.94/24.05/24.57, Loss(train/val/test) 1.90/1.96/1.94. Took 11.69 sec
# Epoch 44, Acc(train/val/test): 25.73/28.52/28.55, Loss(train/val/test) 1.92/1.81/1.82. Took 11.81 sec
# Epoch 45, Acc(train/val/test): 28.94/24.37/23.81, Loss(train/val/test) 1.83/1.99/2.00. Took 11.70 sec
# Epoch 46, Acc(train/val/test): 32.01/28.30/27.10, Loss(train/val/test) 1.77/2.05/2.05. Took 11.70 sec
# Epoch 47, Acc(train/val/test): 32.43/29.45/29.03, Loss(train/val/test) 1.80/2.23/2.27. Took 11.81 sec
# Epoch 48, Acc(train/val/test): 30.81/36.27/36.58, Loss(train/val/test) 1.83/1.74/1.74. Took 11.75 sec
# Epoch 49, Acc(train/val/test): 38.35/39.06/39.99, Loss(train/val/test) 1.64/1.59/1.58. Took 11.99 sec
# Namespace(exp_name='exp1_lr', act='relu', l2=0.001, optim='Adam', lr=0.0015, epoch=50, train_batch_size=512, test_batch_size=1024)
# Epoch 0, Acc(train/val/test): 9.89/10.29/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.65 sec
# Epoch 1, Acc(train/val/test): 9.71/9.98/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.68 sec
# Epoch 2, Acc(train/val/test): 9.77/10.01/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.83 sec
# Epoch 3, Acc(train/val/test): 9.91/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.69 sec
# Epoch 4, Acc(train/val/test): 10.00/10.01/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.70 sec
# Epoch 5, Acc(train/val/test): 9.72/9.89/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.82 sec
# Epoch 6, Acc(train/val/test): 9.73/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.72 sec
# Epoch 7, Acc(train/val/test): 9.66/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.69 sec
# Epoch 8, Acc(train/val/test): 9.96/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.79 sec
# Epoch 9, Acc(train/val/test): 10.08/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.75 sec
# Epoch 10, Acc(train/val/test): 9.68/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.88 sec
# Epoch 11, Acc(train/val/test): 9.80/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.80 sec
# Epoch 12, Acc(train/val/test): 9.96/9.89/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.69 sec
# Epoch 13, Acc(train/val/test): 9.99/9.89/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.84 sec
# Epoch 14, Acc(train/val/test): 9.67/9.89/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.72 sec
# Epoch 15, Acc(train/val/test): 9.94/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.69 sec
# Epoch 16, Acc(train/val/test): 9.99/9.92/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.81 sec
# Epoch 17, Acc(train/val/test): 9.79/10.01/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.69 sec
# Epoch 18, Acc(train/val/test): 10.07/9.92/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.68 sec
# Epoch 19, Acc(train/val/test): 9.72/9.98/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.81 sec
# Epoch 20, Acc(train/val/test): 9.93/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.74 sec
# Epoch 21, Acc(train/val/test): 9.82/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.70 sec
# Epoch 22, Acc(train/val/test): 9.94/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.87 sec
# Epoch 23, Acc(train/val/test): 9.93/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.90 sec
# Epoch 24, Acc(train/val/test): 9.99/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.81 sec
# Epoch 25, Acc(train/val/test): 10.00/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.68 sec
# Epoch 26, Acc(train/val/test): 9.82/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.75 sec
# Epoch 27, Acc(train/val/test): 9.99/9.89/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.80 sec
# Epoch 28, Acc(train/val/test): 9.70/9.92/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.70 sec
# Epoch 29, Acc(train/val/test): 9.92/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.69 sec
# Epoch 30, Acc(train/val/test): 9.94/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.95 sec
# Epoch 31, Acc(train/val/test): 9.86/9.92/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.68 sec
# Epoch 32, Acc(train/val/test): 10.02/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.82 sec
# Epoch 33, Acc(train/val/test): 9.91/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.72 sec
# Epoch 34, Acc(train/val/test): 9.94/9.92/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.70 sec
# Epoch 35, Acc(train/val/test): 9.89/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.84 sec
# Epoch 36, Acc(train/val/test): 9.79/9.89/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.89 sec
# Epoch 37, Acc(train/val/test): 9.76/9.92/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.85 sec
# Epoch 38, Acc(train/val/test): 9.96/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.67 sec
# Epoch 39, Acc(train/val/test): 9.83/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.80 sec
# Epoch 40, Acc(train/val/test): 9.98/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.82 sec
# Epoch 41, Acc(train/val/test): 9.77/10.01/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.77 sec
# Epoch 42, Acc(train/val/test): 9.57/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.76 sec
# Epoch 43, Acc(train/val/test): 9.91/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.69 sec
# Epoch 44, Acc(train/val/test): 9.51/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.71 sec
# Epoch 45, Acc(train/val/test): 9.97/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.75 sec
# Epoch 46, Acc(train/val/test): 10.01/9.89/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.71 sec
# Epoch 47, Acc(train/val/test): 9.85/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.76 sec
# Epoch 48, Acc(train/val/test): 9.94/9.92/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.75 sec
# Epoch 49, Acc(train/val/test): 9.81/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.75 sec
# Namespace(exp_name='exp1_lr', act='relu', l2=0.001, optim='RMSprop', lr=0.0015, epoch=50, train_batch_size=512, test_batch_size=1024)
# Epoch 0, Acc(train/val/test): 9.98/10.01/10.00, Loss(train/val/test) 11.57/2.30/2.30. Took 11.65 sec
# Epoch 1, Acc(train/val/test): 9.99/9.92/10.00, Loss(train/val/test) 2.33/2.30/2.30. Took 11.76 sec
# Epoch 2, Acc(train/val/test): 10.17/9.92/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.69 sec
# Epoch 3, Acc(train/val/test): 9.97/10.16/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.70 sec
# Epoch 4, Acc(train/val/test): 9.76/9.92/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.79 sec
# Epoch 5, Acc(train/val/test): 9.89/10.01/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.74 sec
# Epoch 6, Acc(train/val/test): 9.94/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.70 sec
# Epoch 7, Acc(train/val/test): 9.51/9.89/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.83 sec
# Epoch 8, Acc(train/val/test): 9.89/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.69 sec
# Epoch 9, Acc(train/val/test): 9.75/9.92/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.68 sec
# Epoch 10, Acc(train/val/test): 9.82/10.01/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.84 sec
# Epoch 11, Acc(train/val/test): 9.74/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.73 sec
# Epoch 12, Acc(train/val/test): 9.88/10.01/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.69 sec
# Epoch 13, Acc(train/val/test): 9.79/10.01/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.82 sec
# Epoch 14, Acc(train/val/test): 9.79/9.89/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.70 sec
# Epoch 15, Acc(train/val/test): 9.76/10.08/10.00, Loss(train/val/test) 2.30/2.31/2.31. Took 11.68 sec
# Epoch 16, Acc(train/val/test): 9.73/10.29/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.82 sec
# Epoch 17, Acc(train/val/test): 9.62/9.92/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.72 sec
# Epoch 18, Acc(train/val/test): 9.81/9.92/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.69 sec
# Epoch 19, Acc(train/val/test): 9.57/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.80 sec
# Epoch 20, Acc(train/val/test): 10.07/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.69 sec
# Epoch 21, Acc(train/val/test): 10.00/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.69 sec
# Epoch 22, Acc(train/val/test): 10.03/9.98/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.83 sec
# Epoch 23, Acc(train/val/test): 10.06/10.01/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.69 sec
# Epoch 24, Acc(train/val/test): 10.08/9.92/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.68 sec
# Epoch 25, Acc(train/val/test): 10.00/9.92/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.81 sec
# Epoch 26, Acc(train/val/test): 10.12/10.01/10.00, Loss(train/val/test) 2.30/2.31/2.31. Took 11.69 sec
# Epoch 27, Acc(train/val/test): 9.86/10.06/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.70 sec
# Epoch 28, Acc(train/val/test): 10.03/10.06/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.82 sec
# Epoch 29, Acc(train/val/test): 9.85/9.92/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.74 sec
# Epoch 30, Acc(train/val/test): 9.78/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.69 sec
# Epoch 31, Acc(train/val/test): 9.85/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.80 sec
# Epoch 32, Acc(train/val/test): 9.84/9.92/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.69 sec
# Epoch 33, Acc(train/val/test): 10.04/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.70 sec
# Epoch 34, Acc(train/val/test): 9.97/9.89/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.85 sec
# Epoch 35, Acc(train/val/test): 9.67/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.68 sec
# Epoch 36, Acc(train/val/test): 9.91/9.69/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.80 sec
# Epoch 37, Acc(train/val/test): 10.09/9.92/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.71 sec
# Epoch 38, Acc(train/val/test): 9.80/9.92/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.69 sec
# Epoch 39, Acc(train/val/test): 9.83/9.98/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.79 sec
# Epoch 40, Acc(train/val/test): 9.96/9.98/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.74 sec
# Epoch 41, Acc(train/val/test): 9.64/9.89/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.71 sec
# Epoch 42, Acc(train/val/test): 9.94/10.01/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.77 sec
# Epoch 43, Acc(train/val/test): 10.12/9.98/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.90 sec
# Epoch 44, Acc(train/val/test): 9.80/9.92/10.00, Loss(train/val/test) 2.30/2.30/2.30. Took 11.82 sec
# Epoch 45, Acc(train/val/test): 9.97/10.01/10.00, Loss(train/val/test) 2.30/2.35/2.35. Took 11.89 sec
# Epoch 46, Acc(train/val/test): 12.95/16.88/17.41, Loss(train/val/test) 92.62/2.16/2.14. Took 11.80 sec
# Epoch 47, Acc(train/val/test): 14.82/16.73/17.17, Loss(train/val/test) 2.26/2.13/2.12. Took 11.74 sec
# Epoch 48, Acc(train/val/test): 18.72/16.27/16.83, Loss(train/val/test) 2.09/2.13/2.11. Took 11.67 sec
# Epoch 49, Acc(train/val/test): 19.30/12.71/13.09, Loss(train/val/test) 2.06/2.31/2.30. Took 12.01 sec

# %%
var1 = name_var1
var2 = name_var2
df = load_exp_result('exp1_lr') # 실험결과 불러옴

# %%
df.head()
# Out:
#    Unnamed: 0                                       train_losses  \
# 0           0  [2.29831927335715, 2.0009057431281367, 1.80578...
# 1           0  [13.957337189324294, 2.303221147271651, 2.3030...
# 2           0  [2.3036038483245465, 2.302864539472363, 2.3026...
# 3           0  [11.569377500799638, 2.3263052867937692, 2.302...
#
#                                           val_losses  \
# 0  [2.322308349609375, 1.8739651441574097, 1.7557...
# 1  [2.3404793739318848, 2.3035130500793457, 2.304...
# 2  [2.3025779724121094, 2.3026267766952513, 2.302...
# 3  [2.3026984691619874, 2.3048818826675417, 2.302...
#
#                                            te_losses  train_loss  val_loss  \
# 0  [2.3204334020614623, 1.8671809911727906, 1.752...    0.079445  1.737016
# 1  [2.3418272495269776, 2.3031774044036863, 2.304...    1.637687  1.590865
# 2  [2.302645969390869, 2.3026017904281617, 2.3025...    2.302672  2.302673
# 3  [2.3030338287353516, 2.304623579978943, 2.3026...    2.057474  2.313878
#
#    test_loss                                         train_accs  \
# 0   1.802709  [11.1325, 19.28, 27.6375, 35.3325, 41.77, 48.7...
# 1   1.580618  [10.0075, 9.705, 9.59, 9.83, 9.8025, 9.8675, 9...
# 2   2.302603  [9.8925, 9.7075, 9.7725, 9.9125, 10.0025, 9.72...
# 3   2.303395  [9.985, 9.995, 10.17, 9.9675, 9.76, 9.89, 9.93...
#
#                                             val_accs  \
# 0  [9.07, 23.87, 30.52, 39.8, 46.84, 49.48, 54.15...
# 1  [10.16, 9.89, 10.16, 10.08, 10.16, 10.16, 9.98...
# 2  [10.29, 9.98, 10.01, 9.69, 10.01, 9.89, 9.69, ...
# 3  [10.01, 9.92, 9.92, 10.16, 9.92, 10.01, 9.69, ...
#
#                                            test_accs  train_acc  val_acc  \
# 0  [8.54, 23.73, 30.23, 39.92, 46.52, 49.96, 54.0...     97.325    70.60
# 1  [10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10....     38.350    39.06
# 2  [10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10....      9.815     9.69
# 3  [10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10....     19.300    12.71
#
#    test_acc exp_name   act      l2    optim      lr  train_batch_size
# 0     69.77  exp1_lr  relu  0.0001     Adam  0.0015               512
# 1     39.99  exp1_lr  relu  0.0001  RMSprop  0.0015               512
# 2     10.00  exp1_lr  relu  0.0010     Adam  0.0015               512
# 3     13.09  exp1_lr  relu  0.0010  RMSprop  0.0015               512

# %%
plot_acc(var1, var2, df_new)
