# %% [markdown]
# # AutoML

# %% [markdown]
# # Pycaret
# https://jaylala.tistory.com/entry/머신러닝-with-파이썬-Pycaret이란-Pycaret을-활용한-머신러닝
# https://pycaret.gitbook.io/docs

# %% [markdown]
# !pip install pycaret

# %% [markdown]
# ### venv 또는 uv 를 활용한 가상환경 구축 권장
# (Conda 사용시 환경 충돌 발생)
#
# #### venv 셋업
# python3.11 -m venv .venv
# source .venv/bin/activate
# pip install pycaret xgboost seaborn ipykernel
# !pip install pycaret
#
# #### uv 셋업 (권장)
# (powershell 실행)
# Set-ExecutionPolicy RemoteSigned -Scope CurrentUser
# irm https://astral.sh/uv/install.ps1 | iex
#
# (cmd 실행)
# set Path=C:\Users\User\.local\bin;%Path%
# uv init --python 3.11
# uv add --no-build-isolation pycaret xgboost seaborn ipykernel
# .venv\Scripts\activate.bat

# %%
from pycaret.datasets import get_data
from pycaret.classification import *

# %%
# Iris 내장 데이터 로드
data=get_data('iris')
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
from sklearn.model_selection import train_test_split # datasplit

# %%
# 데이터 나눔
from sklearn.model_selection import train_test_split # datasplit
test_size = 0.2
data_train, data_test = train_test_split(data, test_size=test_size)

# %%
# setup 함수는 Pycaret에서 사용되는 데이터 전처리 및 모델 학습 설정을 수행합니다.
# 데이터 전처리와 모델 학습 설정
exp = setup(data_train, target='species')
# Out:
# <style type="text/css">
# #T_47e26_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_47e26">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47e26_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_47e26_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47e26_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_47e26_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_47e26_row0_col1" class="data row0 col1" >2750</td>
#     </tr>
#     <tr>
#       <th id="T_47e26_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_47e26_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_47e26_row1_col1" class="data row1 col1" >species</td>
#     </tr>
#     <tr>
#       <th id="T_47e26_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_47e26_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_47e26_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_47e26_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_47e26_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_47e26_row3_col1" class="data row3 col1" >Iris-setosa: 0, Iris-versicolor: 1, Iris-virginica: 2</td>
#     </tr>
#     <tr>
#       <th id="T_47e26_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_47e26_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_47e26_row4_col1" class="data row4 col1" >(120, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_47e26_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_47e26_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_47e26_row5_col1" class="data row5 col1" >(120, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_47e26_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_47e26_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_47e26_row6_col1" class="data row6 col1" >(84, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_47e26_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_47e26_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_47e26_row7_col1" class="data row7 col1" >(36, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_47e26_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_47e26_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_47e26_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_47e26_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_47e26_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_47e26_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_47e26_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_47e26_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_47e26_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_47e26_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_47e26_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_47e26_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_47e26_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_47e26_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_47e26_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_47e26_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_47e26_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_47e26_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_47e26_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_47e26_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_47e26_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_47e26_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_47e26_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_47e26_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_47e26_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_47e26_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_47e26_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_47e26_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_47e26_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_47e26_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_47e26_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_47e26_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_47e26_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_47e26_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_47e26_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_47e26_row19_col1" class="data row19 col1" >6e18</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Setup 함수설명
#
# - session_id: 각 실험에 대한 고유한 세션 ID, 이 값은 실험을 추적하고 관리하는데 사용되는 값으로, 임의로 생성
#
# - Target : 목표 변수(타겟)
#
# - Target Type: 목표 변수 (타겟)의 데이터 타입, 자동으로 감지
#
# - Target Mapping : 목표 변수의 종류를 알려줍니다.
#   목표 변수는 setosa, versicolor, virginica 이며, 각 변수들은 분석간 0 / 1 / 2 로 벡터화됨을 의미합니다.
#
# - Original Data Shape: 원본 데이터의 형태, 즉 행과 열의 수를 나타내는 정보
#
# - Transformed Data Shape : 데이터 전처리 후 결과
#
# - Transformed train set shape : 전처리 된 데이터를 학습 데이터로 나눈 결과
#
# - Transformed test set shape : 전처리 된 데이터를 테스트 데이터로 나눈 결과
#
# - Numeric Features  : 데이터셋에서 숫자로 표현된 독립변수 개수
#
# - Preprocess : setup 함수에서 진행한 전처리(Preprocess)여부. 전처리는 1) 결측값 처리, 2) 범주형 변수 인코딩, 3) 데이터 분할(학습 / 테스트), 4) 스케일링(표준화 또는 정규화)
#
# - Imputation type : 결측값을 어떻게 처리할 지
#
# - Numeric Imputation : 숫자형 데이터의 결측값 처리방법
#
# - Categorical Imputation : 범주형 데이터의 결측값 처리 방법
#
# - Fold Generator : k-fold CV를 위해 fold를 만들때 fold를 나누는 방법
#
# - Fold Number : fold의 개수
#
# - cpu_jobs : 병렬 처리에 사용되는 CPU 코어의 개수
#  -1: 시스템에서 사용할 수 있는 모든 CPU를 사용
#
# - Use GPU : GPU를 사용했는지 여부
#
# - Log Experiment : 실험 결과를 로그에 기록하고 관리할지
#
# - Experiment Name : 실험 이름
#
# 출처: https://jaylala.tistory.com/entry/머신러닝-with-파이썬-Pycaret이란-Pycaret을-활용한-머신러닝

# %%
# 모델 비교
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_f277e th {
#   text-align: left;
# }
# #T_f277e_row0_col0, #T_f277e_row1_col0, #T_f277e_row1_col2, #T_f277e_row2_col0, #T_f277e_row2_col1, #T_f277e_row2_col2, #T_f277e_row2_col3, #T_f277e_row2_col4, #T_f277e_row2_col5, #T_f277e_row2_col6, #T_f277e_row2_col7, #T_f277e_row3_col0, #T_f277e_row3_col1, #T_f277e_row3_col2, #T_f277e_row3_col3, #T_f277e_row3_col4, #T_f277e_row3_col5, #T_f277e_row3_col6, #T_f277e_row3_col7, #T_f277e_row4_col0, #T_f277e_row4_col1, #T_f277e_row4_col2, #T_f277e_row4_col3, #T_f277e_row4_col4, #T_f277e_row4_col5, #T_f277e_row4_col6, #T_f277e_row4_col7, #T_f277e_row5_col0, #T_f277e_row5_col1, #T_f277e_row5_col2, #T_f277e_row5_col3, #T_f277e_row5_col4, #T_f277e_row5_col5, #T_f277e_row5_col6, #T_f277e_row5_col7, #T_f277e_row6_col0, #T_f277e_row6_col1, #T_f277e_row6_col2, #T_f277e_row6_col3, #T_f277e_row6_col4, #T_f277e_row6_col5, #T_f277e_row6_col6, #T_f277e_row6_col7, #T_f277e_row7_col0, #T_f277e_row7_col1, #T_f277e_row7_col2, #T_f277e_row7_col3, #T_f277e_row7_col4, #T_f277e_row7_col5, #T_f277e_row7_col6, #T_f277e_row7_col7, #T_f277e_row8_col0, #T_f277e_row8_col1, #T_f277e_row8_col2, #T_f277e_row8_col3, #T_f277e_row8_col4, #T_f277e_row8_col5, #T_f277e_row8_col6, #T_f277e_row8_col7, #T_f277e_row9_col0, #T_f277e_row9_col1, #T_f277e_row9_col2, #T_f277e_row9_col3, #T_f277e_row9_col4, #T_f277e_row9_col5, #T_f277e_row9_col6, #T_f277e_row9_col7, #T_f277e_row10_col0, #T_f277e_row10_col1, #T_f277e_row10_col2, #T_f277e_row10_col3, #T_f277e_row10_col4, #T_f277e_row10_col5, #T_f277e_row10_col6, #T_f277e_row10_col7, #T_f277e_row11_col0, #T_f277e_row11_col1, #T_f277e_row11_col2, #T_f277e_row11_col3, #T_f277e_row11_col4, #T_f277e_row11_col5, #T_f277e_row11_col6, #T_f277e_row11_col7, #T_f277e_row12_col0, #T_f277e_row12_col1, #T_f277e_row12_col2, #T_f277e_row12_col3, #T_f277e_row12_col4, #T_f277e_row12_col5, #T_f277e_row12_col6, #T_f277e_row12_col7, #T_f277e_row13_col0, #T_f277e_row13_col1, #T_f277e_row13_col2, #T_f277e_row13_col3, #T_f277e_row13_col4, #T_f277e_row13_col5, #T_f277e_row13_col6, #T_f277e_row13_col7, #T_f277e_row14_col0, #T_f277e_row14_col1, #T_f277e_row14_col2, #T_f277e_row14_col3, #T_f277e_row14_col4, #T_f277e_row14_col5, #T_f277e_row14_col6, #T_f277e_row14_col7 {
#   text-align: left;
# }
# #T_f277e_row0_col1, #T_f277e_row0_col2, #T_f277e_row0_col3, #T_f277e_row0_col4, #T_f277e_row0_col5, #T_f277e_row0_col6, #T_f277e_row0_col7, #T_f277e_row1_col1, #T_f277e_row1_col3, #T_f277e_row1_col4, #T_f277e_row1_col5, #T_f277e_row1_col6, #T_f277e_row1_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f277e_row0_col8, #T_f277e_row2_col8, #T_f277e_row3_col8, #T_f277e_row4_col8, #T_f277e_row5_col8, #T_f277e_row6_col8, #T_f277e_row7_col8, #T_f277e_row8_col8, #T_f277e_row9_col8, #T_f277e_row10_col8, #T_f277e_row11_col8, #T_f277e_row12_col8, #T_f277e_row13_col8, #T_f277e_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_f277e_row1_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f277e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f277e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f277e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_f277e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_f277e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_f277e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_f277e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_f277e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_f277e_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_f277e_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f277e_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_f277e_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_f277e_row0_col1" class="data row0 col1" >0.9875</td>
#       <td id="T_f277e_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_f277e_row0_col3" class="data row0 col3" >0.9875</td>
#       <td id="T_f277e_row0_col4" class="data row0 col4" >0.9917</td>
#       <td id="T_f277e_row0_col5" class="data row0 col5" >0.9875</td>
#       <td id="T_f277e_row0_col6" class="data row0 col6" >0.9814</td>
#       <td id="T_f277e_row0_col7" class="data row0 col7" >0.9833</td>
#       <td id="T_f277e_row0_col8" class="data row0 col8" >0.1670</td>
#     </tr>
#     <tr>
#       <th id="T_f277e_level0_row1" class="row_heading level0 row1" >lda</th>
#       <td id="T_f277e_row1_col0" class="data row1 col0" >Linear Discriminant Analysis</td>
#       <td id="T_f277e_row1_col1" class="data row1 col1" >0.9875</td>
#       <td id="T_f277e_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_f277e_row1_col3" class="data row1 col3" >0.9875</td>
#       <td id="T_f277e_row1_col4" class="data row1 col4" >0.9917</td>
#       <td id="T_f277e_row1_col5" class="data row1 col5" >0.9875</td>
#       <td id="T_f277e_row1_col6" class="data row1 col6" >0.9814</td>
#       <td id="T_f277e_row1_col7" class="data row1 col7" >0.9833</td>
#       <td id="T_f277e_row1_col8" class="data row1 col8" >0.0020</td>
#     </tr>
#     <tr>
#       <th id="T_f277e_level0_row2" class="row_heading level0 row2" >qda</th>
#       <td id="T_f277e_row2_col0" class="data row2 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_f277e_row2_col1" class="data row2 col1" >0.9750</td>
#       <td id="T_f277e_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_f277e_row2_col3" class="data row2 col3" >0.9750</td>
#       <td id="T_f277e_row2_col4" class="data row2 col4" >0.9875</td>
#       <td id="T_f277e_row2_col5" class="data row2 col5" >0.9729</td>
#       <td id="T_f277e_row2_col6" class="data row2 col6" >0.9636</td>
#       <td id="T_f277e_row2_col7" class="data row2 col7" >0.9701</td>
#       <td id="T_f277e_row2_col8" class="data row2 col8" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_f277e_level0_row3" class="row_heading level0 row3" >nb</th>
#       <td id="T_f277e_row3_col0" class="data row3 col0" >Naive Bayes</td>
#       <td id="T_f277e_row3_col1" class="data row3 col1" >0.9639</td>
#       <td id="T_f277e_row3_col2" class="data row3 col2" >0.9963</td>
#       <td id="T_f277e_row3_col3" class="data row3 col3" >0.9639</td>
#       <td id="T_f277e_row3_col4" class="data row3 col4" >0.9740</td>
#       <td id="T_f277e_row3_col5" class="data row3 col5" >0.9624</td>
#       <td id="T_f277e_row3_col6" class="data row3 col6" >0.9452</td>
#       <td id="T_f277e_row3_col7" class="data row3 col7" >0.9509</td>
#       <td id="T_f277e_row3_col8" class="data row3 col8" >0.1490</td>
#     </tr>
#     <tr>
#       <th id="T_f277e_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_f277e_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_f277e_row4_col1" class="data row4 col1" >0.9639</td>
#       <td id="T_f277e_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_f277e_row4_col3" class="data row4 col3" >0.9639</td>
#       <td id="T_f277e_row4_col4" class="data row4 col4" >0.9740</td>
#       <td id="T_f277e_row4_col5" class="data row4 col5" >0.9624</td>
#       <td id="T_f277e_row4_col6" class="data row4 col6" >0.9452</td>
#       <td id="T_f277e_row4_col7" class="data row4 col7" >0.9509</td>
#       <td id="T_f277e_row4_col8" class="data row4 col8" >0.0090</td>
#     </tr>
#     <tr>
#       <th id="T_f277e_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_f277e_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_f277e_row5_col1" class="data row5 col1" >0.9639</td>
#       <td id="T_f277e_row5_col2" class="data row5 col2" >0.9954</td>
#       <td id="T_f277e_row5_col3" class="data row5 col3" >0.9639</td>
#       <td id="T_f277e_row5_col4" class="data row5 col4" >0.9740</td>
#       <td id="T_f277e_row5_col5" class

# %%
# 가장 결과가 좋았던 QDA를 바탕으로 10 fold CV를 수행한 결과
# 모델 학습과 하이퍼파라미터 튜닝을 자동으로 수행
tuned_model = tune_model(best_model)
# Out:
# <style type="text/css">
# #T_aeb45_row10_col0, #T_aeb45_row10_col1, #T_aeb45_row10_col2, #T_aeb45_row10_col3, #T_aeb45_row10_col4, #T_aeb45_row10_col5, #T_aeb45_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_aeb45">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aeb45_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_aeb45_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_aeb45_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_aeb45_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_aeb45_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_aeb45_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_aeb45_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aeb45_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aeb45_row0_col0" class="data row0 col0" >1.0000</td>
#       <td id="T_aeb45_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_aeb45_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_aeb45_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_aeb45_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_aeb45_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_aeb45_row0_col6" class="data row0 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_aeb45_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_aeb45_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_aeb45_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_aeb45_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_aeb45_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_aeb45_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_aeb45_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_aeb45_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_aeb45_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_aeb45_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_aeb45_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_aeb45_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_aeb45_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_aeb45_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_aeb45_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_aeb45_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_aeb45_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_aeb45_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_aeb45_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_aeb45_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_aeb45_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_aeb45_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_aeb45_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_aeb45_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_aeb45_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_aeb45_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_aeb45_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_aeb45_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_aeb45_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_aeb45_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_aeb45_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_aeb45_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_aeb45_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_aeb45_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_aeb45_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_aeb45_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_aeb45_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_aeb45_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_aeb45_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_aeb45_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_aeb45_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_aeb45_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_aeb45_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_aeb45_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_aeb45_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_aeb45_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_aeb45_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_aeb45_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_aeb45_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_aeb45_row7_col0" class="data row7 col0" >0.8750</td>
#       <td id="T_aeb45_row7_col1" class="data row7 col1" >0.9167</td>
#       <td id="T_aeb45_row7_col2" class="data row7 col2" >0.8750</td>
#       <td id="T_aeb45_row7_col3" class="data row7 col3" >0.9167</td>
#       <td id="T_aeb45_row7_col4" class="data row7 col4" >0.8750</td>
#       <td id="T_aeb45_row7_col5" class="data row7 col5" >0.8140</td>
#       <td id="T_aeb45_row7_col6" class="data row7 col6" >0.8333</td>
#     </tr>
#     <tr>
#       <th id="T_aeb45_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_aeb45_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_aeb45_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_aeb45_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_aeb45_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_aeb45_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_aeb45_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_aeb45_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_aeb45_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_aeb45_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_aeb45_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_aeb45_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_aeb45_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_aeb45_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_aeb45_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_aeb45_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_aeb45_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_aeb45_row10_col0" class="data row10 col0" >0.9875</td>
#       <td id="T_aeb45_row10_col1" class="data row10 col1" >0.9917</td>
#       <td id="T_aeb45_row10_col2" class="data row10 col2" >0.9875</td>
#       <td id="T_aeb45_row10_col3" class="data row10 col3" >0.9917</td>
#       <td id="T_aeb45_row10_col4" class="data row10 col4" >0.9875</td>
#       <td id="T_aeb45_row10_col5" class="data row10 col5" >0.9814</td>
#       <td id="T_aeb45_row10_col6" class="data row10 col6" >0.9833</td>
#     </tr>
#     <tr>
#       <th id="T_aeb45_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_aeb45_row11_col0" class="data row11 col0" >0.0375</td>
#       <td id="T_aeb45_row11_col1" class="data row11 col1" >0.0250</td>
#       <td id="T_aeb45_row11_col2" class="data row11 col2" >0.0375</td>
#       <td id="T_aeb45_row11_col3" class="data row11 col3" >0.0250</td>
#       <td id="T_aeb45_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
# 모델 평가
evaluate_model(tuned_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# 예측을 위한 test data
test_data = data_test

# %%
# 예측 수행
pred = predict_model(tuned_model, data=test_data)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1c5bf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c5bf_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1c5bf_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_1c5bf_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_1c5bf_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_1c5bf_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_1c5bf_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_1c5bf_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_1c5bf_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c5bf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1c5bf_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_1c5bf_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_1c5bf_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_1c5bf_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_1c5bf_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_1c5bf_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_1c5bf_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_1c5bf_row0_col7" class="data row0 col7" >1.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 단일 모델만 선택해서 학습
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# knn       sklearn.neighbors._classification.KNeighborsCl...   True
# nb                           sklearn.naive_bayes.GaussianNB   True
# dt             sklearn.tree._classes.DecisionTreeClassifier   True
# svm       sklearn.linear_model._stochastic_gradient.SGDC...   True
# rbfsvm                             sklearn.svm._classes.SVC  False
# gpc       sklearn.gaussian_process._gpc.GaussianProcessC...  False
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# ridge           sklearn.linear_model._ridge.RidgeClassifier   True
# rf          sklearn.ensemble._forest.RandomForestClassifier   True
# qda       sklearn.discriminant_analysis.QuadraticDiscrim...   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostClas...   True
# gbc         sklearn.ensemble._gb.GradientBoostingClassifier   True
# lda       sklearn.discriminant_analysis.LinearDiscrimina...   True
# et            sklearn.ensemble._forest.ExtraTreesClassifier   True
# xgboost                       xgboost.sklearn.XGBClassifier   True
# lightgbm                    lightgbm.sklearn.LGBMClassifier   True
# dummy                         sklearn.dummy.DummyClassifier   True

# %%
select_model = create_model('rf')
tuned_model = tune_model(select_model)
# Out:
# <style type="text/css">
# #T_b92fc_row10_col0, #T_b92fc_row10_col1, #T_b92fc_row10_col2, #T_b92fc_row10_col3, #T_b92fc_row10_col4, #T_b92fc_row10_col5, #T_b92fc_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_b92fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b92fc_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_b92fc_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_b92fc_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_b92fc_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_b92fc_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_b92fc_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_b92fc_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b92fc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b92fc_row0_col0" class="data row0 col0" >0.8889</td>
#       <td id="T_b92fc_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_b92fc_row0_col2" class="data row0 col2" >0.8889</td>
#       <td id="T_b92fc_row0_col3" class="data row0 col3" >0.9167</td>
#       <td id="T_b92fc_row0_col4" class="data row0 col4" >0.8857</td>
#       <td id="T_b92fc_row0_col5" class="data row0 col5" >0.8333</td>
#       <td id="T_b92fc_row0_col6" class="data row0 col6" >0.8492</td>
#     </tr>
#     <tr>
#       <th id="T_b92fc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b92fc_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_b92fc_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_b92fc_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_b92fc_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_b92fc_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_b92fc_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_b92fc_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_b92fc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b92fc_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_b92fc_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_b92fc_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_b92fc_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_b92fc_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_b92fc_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_b92fc_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_b92fc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b92fc_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_b92fc_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_b92fc_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_b92fc_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_b92fc_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_b92fc_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_b92fc_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_b92fc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b92fc_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_b92fc_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_b92fc_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_b92fc_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_b92fc_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_b92fc_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_b92fc_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_b92fc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b92fc_row5_col0" class="data row5 col0" >0.8750</td>
#       <td id="T_b92fc_row5_col1" class="data row5 col1" >0.9542</td>
#       <td id="T_b92fc_row5_col2" class="data row5 col2" >0.8750</td>
#       <td id="T_b92fc_row5_col3" class="data row5 col3" >0.9062</td>
#       <td id="T_b92fc_row5_col4" class="data row5 col4" >0.8631</td>
#       <td id="T_b92fc_row5_col5" class="data row5 col5" >0.8049</td>
#       <td id="T_b92fc_row5_col6" class="data row5 col6" >0.8260</td>
#     </tr>
#     <tr>
#       <th id="T_b92fc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b92fc_row6_col0" class="data row6 col0" >0.8750</td>
#       <td id="T_b92fc_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_b92fc_row6_col2" class="data row6 col2" >0.8750</td>
#       <td id="T_b92fc_row6_col3" class="data row6 col3" >0.9062</td>
#       <td id="T_b92fc_row6_col4" class="data row6 col4" >0.8631</td>
#       <td id="T_b92fc_row6_col5" class="data row6 col5" >0.8049</td>
#       <td id="T_b92fc_row6_col6" class="data row6 col6" >0.8260</td>
#     </tr>
#     <tr>
#       <th id="T_b92fc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b92fc_row7_col0" class="data row7 col0" >0.8750</td>
#       <td id="T_b92fc_row7_col1" class="data row7 col1" >0.9542</td>
#       <td id="T_b92fc_row7_col2" class="data row7 col2" >0.8750</td>
#       <td id="T_b92fc_row7_col3" class="data row7 col3" >0.9167</td>
#       <td id="T_b92fc_row7_col4" class="data row7 col4" >0.8750</td>
#       <td id="T_b92fc_row7_col5" class="data row7 col5" >0.8140</td>
#       <td id="T_b92fc_row7_col6" class="data row7 col6" >0.8333</td>
#     </tr>
#     <tr>
#       <th id="T_b92fc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b92fc_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_b92fc_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_b92fc_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_b92fc_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_b92fc_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_b92fc_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_b92fc_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_b92fc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b92fc_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_b92fc_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_b92fc_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_b92fc_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_b92fc_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_b92fc_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_b92fc_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_b92fc_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_b92fc_row10_col0" class="data row10 col0" >0.9514</td>
#       <td id="T_b92fc_row10_col1" class="data row10 col1" >0.9908</td>
#       <td id="T_b92fc_row10_col2" class="data row10 col2" >0.9514</td>
#       <td id="T_b92fc_row10_col3" class="data row10 col3" >0.9646</td>
#       <td id="T_b92fc_row10_col4" class="data row10 col4" >0.9487</td>
#       <td id="T_b92fc_row10_col5" class="data row10 col5" >0.9257</td>
#       <td id="T_b92fc_row10_col6" class="data row10 col6" >0.9335</td>
#     </tr>
#     <tr>
#       <th id="T_b92fc_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_b92fc_row11_col0" class="data row11 col0" >0.0597</td>
#       <td id="T_b92fc_row11_col1" class="data row11 col1" >0.0183</td>
#       <td id="T_b92fc_row11_col2" class="data row11 col2" >0.0597</td>
#       <td id="T_b92fc_row11_col3" class="data row11 col3" >0.0435</td>
#       <td id="T_b92fc_row11_col4
# <style type="text/css">
# #T_e3f0c_row10_col0, #T_e3f0c_row10_col1, #T_e3f0c_row10_col2, #T_e3f0c_row10_col3, #T_e3f0c_row10_col4, #T_e3f0c_row10_col5, #T_e3f0c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_e3f0c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3f0c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_e3f0c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_e3f0c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_e3f0c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_e3f0c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_e3f0c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_e3f0c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3f0c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e3f0c_row0_col0" class="data row0 col0" >0.8889</td>
#       <td id="T_e3f0c_row0_col1" class="data row0 col1" >0.9630</td>
#       <td id="T_e3f0c_row0_col2" class="data row0 col2" >0.8889</td>
#       <td id="T_e3f0c_row0_col3" class="data row0 col3" >0.9167</td>
#       <td id="T_e3f0c_row0_col4" class="data row0 col4" >0.8857</td>
#       <td id="T_e3f0c_row0_col5" class="data row0 col5" >0.8333</td>
#       <td id="T_e3f0c_row0_col6" class="data row0 col6" >0.8492</td>
#     </tr>
#     <tr>
#       <th id="T_e3f0c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e3f0c_row1_col0" class="data row1 col0" >1.0000</td>
#       <td id="T_e3f0c_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_e3f0c_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_e3f0c_row1_col3" class="data row1 col3" >1.0000</td>
#       <td id="T_e3f0c_row1_col4" class="data row1 col4" >1.0000</td>
#       <td id="T_e3f0c_row1_col5" class="data row1 col5" >1.0000</td>
#       <td id="T_e3f0c_row1_col6" class="data row1 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_e3f0c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e3f0c_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_e3f0c_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_e3f0c_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_e3f0c_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_e3f0c_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_e3f0c_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_e3f0c_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_e3f0c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e3f0c_row3_col0" class="data row3 col0" >1.0000</td>
#       <td id="T_e3f0c_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_e3f0c_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_e3f0c_row3_col3" class="data row3 col3" >1.0000</td>
#       <td id="T_e3f0c_row3_col4" class="data row3 col4" >1.0000</td>
#       <td id="T_e3f0c_row3_col5" class="data row3 col5" >1.0000</td>
#       <td id="T_e3f0c_row3_col6" class="data row3 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_e3f0c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e3f0c_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_e3f0c_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_e3f0c_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_e3f0c_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_e3f0c_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_e3f0c_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_e3f0c_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_e3f0c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e3f0c_row5_col0" class="data row5 col0" >0.7500</td>
#       <td id="T_e3f0c_row5_col1" class="data row5 col1" >0.9542</td>
#       <td id="T_e3f0c_row5_col2" class="data row5 col2" >0.7500</td>
#       <td id="T_e3f0c_row5_col3" class="data row5 col3" >0.7500</td>
#       <td id="T_e3f0c_row5_col4" class="data row5 col4" >0.7500</td>
#       <td id="T_e3f0c_row5_col5" class="data row5 col5" >0.6190</td>
#       <td id="T_e3f0c_row5_col6" class="data row5 col6" >0.6190</td>
#     </tr>
#     <tr>
#       <th id="T_e3f0c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e3f0c_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_e3f0c_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_e3f0c_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_e3f0c_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_e3f0c_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_e3f0c_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_e3f0c_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_e3f0c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e3f0c_row7_col0" class="data row7 col0" >0.8750</td>
#       <td id="T_e3f0c_row7_col1" class="data row7 col1" >0.9542</td>
#       <td id="T_e3f0c_row7_col2" class="data row7 col2" >0.8750</td>
#       <td id="T_e3f0c_row7_col3" class="data row7 col3" >0.9167</td>
#       <td id="T_e3f0c_row7_col4" class="data row7 col4" >0.8750</td>
#       <td id="T_e3f0c_row7_col5" class="data row7 col5" >0.8140</td>
#       <td id="T_e3f0c_row7_col6" class="data row7 col6" >0.8333</td>
#     </tr>
#     <tr>
#       <th id="T_e3f0c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e3f0c_row8_col0" class="data row8 col0" >1.0000</td>
#       <td id="T_e3f0c_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_e3f0c_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_e3f0c_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_e3f0c_row8_col4" class="data row8 col4" >1.0000</td>
#       <td id="T_e3f0c_row8_col5" class="data row8 col5" >1.0000</td>
#       <td id="T_e3f0c_row8_col6" class="data row8 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_e3f0c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e3f0c_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_e3f0c_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_e3f0c_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_e3f0c_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_e3f0c_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_e3f0c_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_e3f0c_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_e3f0c_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_e3f0c_row10_col0" class="data row10 col0" >0.9514</td>
#       <td id="T_e3f0c_row10_col1" class="data row10 col1" >0.9871</td>
#       <td id="T_e3f0c_row10_col2" class="data row10 col2" >0.9514</td>
#       <td id="T_e3f0c_row10_col3" class="data row10 col3" >0.9583</td>
#       <td id="T_e3f0c_row10_col4" class="data row10 col4" >0.9511</td>
#       <td id="T_e3f0c_row10_col5" class="data row10 col5" >0.9266</td>
#       <td id="T_e3f0c_row10_col6" class="data row10 col6" >0.9302</td>
#     </tr>
#     <tr>
#       <th id="T_e3f0c_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_e3f0c_row11_col0" class="data row11 col0" >0.0818</td>
#       <td id="T_e3f0c_row11_col1" class="data row11 col1" >0.0198</td>
#       <td id="T_e3f0c_row11_col2" class="data row11 col2" >0.0818</td>
#       <td id="T_e3f0c_row11_col3" class="data row11 col3" >0.0768</td>
#       <td id="T_e3f0c_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
evaluate_model(tuned_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# # OPTUNA

# %%
import optuna

def objective(trial):
    x = trial.suggest_float('x', -10, 10)
    return (x - 2) ** 2

study = optuna.create_study()
study.optimize(objective, n_trials=50)

study.best_params
# Out:
# [I 2025-09-29 10:51:57,992] A new study created in memory with name: no-name-3b3fbebc-99c5-4af3-818d-43999dc3dd1f
# [I 2025-09-29 10:51:57,993] Trial 0 finished with value: 0.4023829604561254 and parameters: {'x': 1.365663369766395}. Best is trial 0 with value: 0.4023829604561254.
# [I 2025-09-29 10:51:57,993] Trial 1 finished with value: 9.181026787917794 and parameters: {'x': 5.030020922026413}. Best is trial 0 with value: 0.4023829604561254.
# [I 2025-09-29 10:51:57,993] Trial 2 finished with value: 5.1781956146592245 and parameters: {'x': 4.275564900120237}. Best is trial 0 with value: 0.4023829604561254.
# [I 2025-09-29 10:51:57,993] Trial 3 finished with value: 53.78491294183836 and parameters: {'x': -5.333819805656419}. Best is trial 0 with value: 0.4023829604561254.
# [I 2025-09-29 10:51:57,994] Trial 4 finished with value: 0.20804194417904848 and parameters: {'x': 2.456116152069896}. Best is trial 4 with value: 0.20804194417904848.
# [I 2025-09-29 10:51:57,994] Trial 5 finished with value: 86.79359786746174 and parameters: {'x': -7.316308167265708}. Best is trial 4 with value: 0.20804194417904848.
# [I 2025-09-29 10:51:57,995] Trial 6 finished with value: 0.06353593972068122 and parameters: {'x': 1.7479366355047183}. Best is trial 6 with value: 0.06353593972068122.
# [I 2025-09-29 10:51:57,995] Trial 7 finished with value: 0.17640315200526563 and parameters: {'x': 1.5799962476295413}. Best is trial 6 with value: 0.06353593972068122.
# [I 2025-09-29 10:51:57,996] Trial 8 finished with value: 8.044106226871824 and parameters: {'x': 4.836213360604562}. Best is trial 6 with value: 0.06353593972068122.
# [I 2025-09-29 10:51:57,996] Trial 9 finished with value: 12.42996293179366 and parameters: {'x': -1.525615255780707}. Best is trial 6 with value: 0.06353593972068122.
# [I 2025-09-29 10:51:57,998] Trial 10 finished with value: 60.37942701629514 and parameters: {'x': 9.770420002567116}. Best is trial 6 with value: 0.06353593972068122.
# [I 2025-09-29 10:51:57,999] Trial 11 finished with value: 15.57427482196205 and parameters: {'x': -1.9464255753734985}. Best is trial 6 with value: 0.06353593972068122.
# [I 2025-09-29 10:51:58,000] Trial 12 finished with value: 41.77693937527454 and parameters: {'x': 8.463508286934777}. Best is trial 6 with value: 0.06353593972068122.
# [I 2025-09-29 10:51:58,002] Trial 13 finished with value: 31.39883951440252 and parameters: {'x': -3.603466740724221}. Best is trial 6 with value: 0.06353593972068122.
# [I 2025-09-29 10:51:58,003] Trial 14 finished with value: 2.6036347822426213 and parameters: {'x': 0.3864217458571706}. Best is trial 6 with value: 0.06353593972068122.
# [I 2025-09-29 10:51:58,004] Trial 15 finished with value: 125.6667241302346 and parameters: {'x': -9.21011704355644}. Best is trial 6 with value: 0.06353593972068122.
# [I 2025-09-29 10:51:58,005] Trial 16 finished with value: 27.113292407441797 and parameters: {'x': 7.207042577840304}. Best is trial 6 with value: 0.06353593972068122.
# [I 2025-09-29 10:51:58,006] Trial 17 finished with value: 0.9209810460552814 and parameters: {'x': 2.95967757400873}. Best is trial 6 with value: 0.06353593972068122.
# [I 2025-09-29 10:51:58,007] Trial 18 finished with value: 5.9421419616964535 and parameters: {'x': -0.43765091054819694}. Best is trial 6 with value: 0.06353593972068122.
# [I 2025-09-29 10:51:58,008] Trial 19 finished with value: 36.65389466799713 and parameters: {'x': -4.054246003260615}. Best is trial 6 with value: 0.06353593972068122.
# [I 2025-09-29 10:51:58,009] Trial 20 finished with value: 22.140940596717876 and parameters: {'x': 6.705416091773168}. Best is trial 6 with value: 0.06353593972068122.
# [I 2025-09-29 10:51:58,010] Trial 21 finished with value: 0.009082782243610433 and parameters: {'x': 2.0953036318490037}. Best is trial 21 with value: 0.009082782243610433.
# [I 2025-09-29 10:51:58,011] Trial 22 finished with value: 0.0006968849640919462 and parameters: {'x': 2.0263985788271253}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,012] Trial 23 finished with value: 2.47792609538185 and parameters: {'x': 3.5741429717093203}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,013] Trial 24 finished with value: 5.607436025787562 and parameters: {'x': -0.3680025392274313}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,014] Trial 25 finished with value: 17.655931282451565 and parameters: {'x': 6.201896153220777}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,015] Trial 26 finished with value: 0.8837949851530572 and parameters: {'x': 1.0598962902141822}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,016] Trial 27 finished with value: 22.31517791976577 and parameters: {'x': -2.7238943595052767}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,017] Trial 28 finished with value: 0.08334924335190932 and parameters: {'x': 2.288702690240166}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,018] Trial 29 finished with value: 7.781836884008569 and parameters: {'x': -0.78959439417428}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,019] Trial 30 finished with value: 1.9876794635602375 and parameters: {'x': 0.5901491342839706}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,020] Trial 31 finished with value: 0.0054638675937924205 and parameters: {'x': 2.073917978826483}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,021] Trial 32 finished with value: 12.658995934320588 and parameters: {'x': 5.5579482759478935}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,022] Trial 33 finished with value: 3.0192115676456046 and parameters: {'x': 3.7375878589716276}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,023] Trial 34 finished with value: 0.007447987693349067 and parameters: {'x': 1.9136982752585496}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,024] Trial 35 finished with value: 7.033753746343949 and parameters: {'x': 4.652122498366912}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,024] Trial 36 finished with value: 1.8493095699585682 and parameters: {'x': 3.359893220057578}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,027] Trial 37 finished with value: 0.1505873254640347 and parameters: {'x': 1.6119441722328671}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,028] Trial 38 finished with value: 0.3922843727710026 and parameters: {'x': 2.6263260914020767}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,029] Trial 39 finished with value: 2.004292726327504 and parameters: {'x': 0.5842695431942195}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,030] Trial 40 finished with value: 62.005843205023325 and parameters: {'x': -5.874378909159968}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,031] Trial 41 finished with value: 0.05296401143583163 and parameters: {'x': 1.7698608867753427}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,032] Trial 42 finished with value: 0.22774066679655688 and parameters: {'x': 1.5227781786249115}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,034] Trial 43 finished with value: 5.682648557232263 and parameters: {'x': 4.383830647766796}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,035] Trial 44 finished with value: 11.937501963614741 and parameters: {'x': -1.455069024435654}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,036] Trial 45 finished with value: 12.242192870095508 and parameters: {'x': 5.498884517970764}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,037] Trial 46 finished with value: 0.33232641234348687 and parameters: {'x': 2.576477590495491}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,038] Trial 47 finished with value: 0.016022729878749635 and parameters: {'x': 2.126580922254302}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,039] Trial 48 finished with value: 3.6171871325277265 and parameters: {'x': 3.9018904102307594}. Best is trial 22 with value: 0.0006968849640919462.
# [I 2025-09-29 10:51:58,040] Trial 49 finished with value: 4.341969863238691 and parameters: {'x': -0.08373939427143604}. Best is trial 22 with value: 0.0006968849640919462.
# {'x': 2.0263985788271253}

# %% [markdown]
# # Optuna로 data_train 기반 모델/하이퍼파라미터 탐색
# - 목적: data_train에서 교차검증 정확도를 최대화하는 모델과 파라미터 찾기
# - 대상 모델: LogisticRegression, RandomForest, SVC, KNN
# - 평가: Stratified 5-Fold Accuracy

# %%
# --- 1) Imports & helpers
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold, cross_val_score, train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
import optuna

# --- 2) Prepare X, y from data_train

X = data_train.drop(columns=['species'])
y = data_train['species']

# train/validation split for final holdout test (optional)
X_tr, X_val, y_tr, y_val = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# --- 3) Define search space and objective
MODEL_CHOICES = ['logreg', 'rf', 'svc', 'knn']

def make_pipeline(trial, model_key):
    scaler = StandardScaler()

    if model_key == 'logreg':
        C = trial.suggest_float('logreg_C', 1e-3, 1e3, log=True)
        solver = trial.suggest_categorical('logreg_solver', ['lbfgs', 'liblinear'])
        max_iter = trial.suggest_int('logreg_max_iter', 200, 1000)
        clf = LogisticRegression(C=C, solver=solver, max_iter=max_iter, n_jobs=None)
    elif model_key == 'rf':
        n_estimators = trial.suggest_int('rf_n_estimators', 50, 400)
        max_depth = trial.suggest_int('rf_max_depth', 2, 20)
        min_samples_split = trial.suggest_int('rf_min_samples_split', 2, 10)
        min_samples_leaf = trial.suggest_int('rf_min_samples_leaf', 1, 5)
        clf = RandomForestClassifier(
            n_estimators=n_estimators,
            max_depth=max_depth,
            min_samples_split=min_samples_split,
            min_samples_leaf=min_samples_leaf,
            random_state=42,
        )
    elif model_key == 'svc':
        C = trial.suggest_float('svc_C', 1e-3, 1e3, log=True)
        gamma = trial.suggest_float('svc_gamma', 1e-4, 1e0, log=True)
        kernel = trial.suggest_categorical('svc_kernel', ['rbf', 'poly'])
        degree = 3 if kernel != 'poly' else trial.suggest_int('svc_degree', 2, 5)
        clf = SVC(C=C, gamma=gamma, kernel=kernel, degree=degree)
    elif model_key == 'knn':
        n_neighbors = trial.suggest_int('knn_n_neighbors', 1, 30)
        weights = trial.suggest_categorical('knn_weights', ['uniform', 'distance'])
        p = trial.suggest_int('knn_p', 1, 2)  # 1=Manhattan, 2=Euclidean
        clf = KNeighborsClassifier(n_neighbors=n_neighbors, weights=weights, p=p)
    else:
        raise ValueError(f"Unknown model key: {model_key}")

    return Pipeline([
        ('scaler', scaler),
        ('clf', clf)
    ])


def objective(trial):
    model_key = trial.suggest_categorical('model', MODEL_CHOICES)
    pipe = make_pipeline(trial, model_key)

    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(pipe, X_tr, y_tr, cv=cv, scoring='accuracy', n_jobs=None)
    return scores.mean()

# --- 4) Run study
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50, show_progress_bar=False)

print('Best value (CV accuracy):', study.best_value)
print('Best params:', study.best_params)

# --- 5) Refit best pipeline on the full training split, evaluate on validation
best_model_key = study.best_params['model']
best_pipe = make_pipeline(study.best_trial, best_model_key)
best_pipe.fit(X_tr, y_tr)

val_pred = best_pipe.predict(X_val)
val_acc = accuracy_score(y_val, val_pred)
print('\nHoldout validation accuracy:', val_acc)
print('\nClassification report:\n', classification_report(y_val, val_pred))
# Out:
# [I 2025-09-29 10:54:47,139] A new study created in memory with name: no-name-8360bcc4-156c-4a18-a72c-ff8b0d0d1639
# [I 2025-09-29 10:54:47,156] Trial 0 finished with value: 0.8231578947368421 and parameters: {'model': 'logreg', 'logreg_C': 0.016640648224252243, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 375}. Best is trial 0 with value: 0.8231578947368421.
# [I 2025-09-29 10:54:47,172] Trial 1 finished with value: 0.9368421052631579 and parameters: {'model': 'logreg', 'logreg_C': 0.366256128434209, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 972}. Best is trial 1 with value: 0.9368421052631579.
# [I 2025-09-29 10:54:47,184] Trial 2 finished with value: 0.32263157894736844 and parameters: {'model': 'svc', 'svc_C': 604.0936923978701, 'svc_gamma': 0.017783542735429595, 'svc_kernel': 'poly', 'svc_degree': 5}. Best is trial 1 with value: 0.9368421052631579.
# [I 2025-09-29 10:54:47,196] Trial 3 finished with value: 0.3326315789473685 and parameters: {'model': 'svc', 'svc_C': 26.930567891336676, 'svc_gamma': 0.005038956219469749, 'svc_kernel': 'poly', 'svc_degree': 4}. Best is trial 1 with value: 0.9368421052631579.
# [I 2025-09-29 10:54:47,207] Trial 4 finished with value: 0.9263157894736842 and parameters: {'model': 'knn', 'knn_n_neighbors': 15, 'knn_weights': 'distance', 'knn_p': 1}. Best is trial 1 with value: 0.9368421052631579.
# [I 2025-09-29 10:54:47,218] Trial 5 finished with value: 0.9368421052631579 and parameters: {'model': 'logreg', 'logreg_C': 667.9967960280145, 'logreg_solver': 'liblinear', 'logreg_max_iter': 662}. Best is trial 1 with value: 0.9368421052631579.
# [I 2025-09-29 10:54:47,230] Trial 6 finished with value: 0.9263157894736842 and parameters: {'model': 'knn', 'knn_n_neighbors': 26, 'knn_weights': 'distance', 'knn_p': 1}. Best is trial 1 with value: 0.9368421052631579.
# [I 2025-09-29 10:54:47,240] Trial 7 finished with value: 0.791578947368421 and parameters: {'model': 'logreg', 'logreg_C': 0.00945365452573685, 'logreg_solver': 'liblinear', 'logreg_max_iter': 296}. Best is trial 1 with value: 0.9368421052631579.
# [I 2025-09-29 10:54:47,257] Trial 8 finished with value: 0.9578947368421054 and parameters: {'model': 'logreg', 'logreg_C': 101.55111984826345, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 988}. Best is trial 8 with value: 0.9578947368421054.
# [I 2025-09-29 10:54:47,268] Trial 9 finished with value: 0.39263157894736844 and parameters: {'model': 'svc', 'svc_C': 24.928178593591582, 'svc_gamma': 0.0003339629111139219, 'svc_kernel': 'poly', 'svc_degree': 2}. Best is trial 8 with value: 0.9578947368421054.
# [I 2025-09-29 10:54:47,817] Trial 10 finished with value: 0.9368421052631579 and parameters: {'model': 'rf', 'rf_n_estimators': 259, 'rf_max_depth': 2, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 3}. Best is trial 8 with value: 0.9578947368421054.
# [I 2025-09-29 10:54:47,835] Trial 11 finished with value: 0.968421052631579 and parameters: {'model': 'logreg', 'logreg_C': 27.706013348930405, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 972}. Best is trial 11 with value: 0.968421052631579.
# [I 2025-09-29 10:54:47,854] Trial 12 finished with value: 0.9578947368421054 and parameters: {'model': 'logreg', 'logreg_C': 49.60456909042373, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 1000}. Best is trial 11 with value: 0.968421052631579.
# [I 2025-09-29 10:54:47,975] Trial 13 finished with value: 0.9473684210526315 and parameters: {'model': 'rf', 'rf_n_estimators': 50, 'rf_max_depth': 19, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 5}. Best is trial 11 with value: 0.968421052631579.
# [I 2025-09-29 10:54:47,993] Trial 14 finished with value: 0.9789473684210526 and parameters: {'model': 'logreg', 'logreg_C': 15.01044022162816, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 775}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:48,008] Trial 15 finished with value: 0.968421052631579 and parameters: {'model': 'logreg', 'logreg_C': 3.747958439889271, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 727}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:48,024] Trial 16 finished with value: 0.968421052631579 and parameters: {'model': 'logreg', 'logreg_C': 2.9153751143960265, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 792}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:48,040] Trial 17 finished with value: 0.8842105263157893 and parameters: {'model': 'knn', 'knn_n_neighbors': 1, 'knn_weights': 'uniform', 'knn_p': 2}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:48,863] Trial 18 finished with value: 0.9268421052631579 and parameters: {'model': 'rf', 'rf_n_estimators': 390, 'rf_max_depth': 8, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:48,881] Trial 19 finished with value: 0.968421052631579 and parameters: {'model': 'logreg', 'logreg_C': 20.231966028808483, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 823}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:48,894] Trial 20 finished with value: 0.8336842105263157 and parameters: {'model': 'logreg', 'logreg_C': 0.6697647141703232, 'logreg_solver': 'liblinear', 'logreg_max_iter': 519}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:48,911] Trial 21 finished with value: 0.9789473684210526 and parameters: {'model': 'logreg', 'logreg_C': 6.724323550492249, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 762}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:48,928] Trial 22 finished with value: 0.9789473684210526 and parameters: {'model': 'logreg', 'logreg_C': 10.184340049196262, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 856}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:48,945] Trial 23 finished with value: 0.9789473684210526 and parameters: {'model': 'logreg', 'logreg_C': 5.67901774689182, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 839}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:48,959] Trial 24 finished with value: 0.8542105263157895 and parameters: {'model': 'logreg', 'logreg_C': 0.10349676140030717, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 559}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:48,979] Trial 25 finished with value: 0.9578947368421054 and parameters: {'model': 'logreg', 'logreg_C': 374.0992251846401, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 860}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:49,104] Trial 26 finished with value: 0.9368421052631579 and parameters: {'model': 'rf', 'rf_n_estimators': 54, 'rf_max_depth': 20, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 5}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:49,119] Trial 27 finished with value: 0.874736842105263 and parameters: {'model': 'knn', 'knn_n_neighbors': 30, 'knn_weights': 'uniform', 'knn_p': 2}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:49,133] Trial 28 finished with value: 0.39263157894736844 and parameters: {'model': 'svc', 'svc_C': 0.0010562328112842963, 'svc_gamma': 0.4026536459938309, 'svc_kernel': 'rbf'}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:49,151] Trial 29 finished with value: 0.9789473684210526 and parameters: {'model': 'logreg', 'logreg_C': 8.752329750979506, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 706}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:49,164] Trial 30 finished with value: 0.8436842105263157 and parameters: {'model': 'logreg', 'logreg_C': 1.0319429952205446, 'logreg_solver': 'liblinear', 'logreg_max_iter': 649}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:49,182] Trial 31 finished with value: 0.9789473684210526 and parameters: {'model': 'logreg', 'logreg_C': 6.862556140987512, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 868}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:49,201] Trial 32 finished with value: 0.9578947368421054 and parameters: {'model': 'logreg', 'logreg_C': 69.97172461165333, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 771}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:49,218] Trial 33 finished with value: 0.968421052631579 and parameters: {'model': 'logreg', 'logreg_C': 2.1614640886498853, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 892}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:49,236] Trial 34 finished with value: 0.9789473684210526 and parameters: {'model': 'logreg', 'logreg_C': 10.960631584930436, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 893}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:49,251] Trial 35 finished with value: 0.39263157894736844 and parameters: {'model': 'svc', 'svc_C': 0.005278147876603407, 'svc_gamma': 0.8231010335272384, 'svc_kernel': 'rbf'}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:49,270] Trial 36 finished with value: 0.9578947368421054 and parameters: {'model': 'logreg', 'logreg_C': 173.71323511087928, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 735}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:49,285] Trial 37 finished with value: 0.7700000000000001 and parameters: {'model': 'logreg', 'logreg_C': 0.0015278221246948695, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 806}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:49,309] Trial 38 finished with value: 0.9368421052631579 and parameters: {'model': 'knn', 'knn_n_neighbors': 4, 'knn_weights': 'distance', 'knn_p': 1}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:49,331] Trial 39 finished with value: 0.968421052631579 and parameters: {'model': 'logreg', 'logreg_C': 21.209935194081247, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 631}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:49,344] Trial 40 finished with value: 0.39263157894736844 and parameters: {'model': 'svc', 'svc_C': 0.10693719693847, 'svc_gamma': 0.00036454089299490307, 'svc_kernel': 'rbf'}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:49,361] Trial 41 finished with value: 0.9789473684210526 and parameters: {'model': 'logreg', 'logreg_C': 7.287037932611089, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 699}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:49,378] Trial 42 finished with value: 0.9789473684210526 and parameters: {'model': 'logreg', 'logreg_C': 8.506670774997467, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 752}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:49,395] Trial 43 finished with value: 0.9578947368421051 and parameters: {'model': 'logreg', 'logreg_C': 1.679439230323316, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 830}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:49,412] Trial 44 finished with value: 0.968421052631579 and parameters: {'model': 'logreg', 'logreg_C': 20.958417779269265, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 907}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:49,428] Trial 45 finished with value: 0.9163157894736841 and parameters: {'model': 'logreg', 'logreg_C': 0.21417938816116475, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 681}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:49,446] Trial 46 finished with value: 0.9789473684210526 and parameters: {'model': 'logreg', 'logreg_C': 4.521645833998455, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 460}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:49,893] Trial 47 finished with value: 0.9473684210526315 and parameters: {'model': 'rf', 'rf_n_estimators': 209, 'rf_max_depth': 11, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 1}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:49,909] Trial 48 finished with value: 0.9063157894736842 and parameters: {'model': 'knn', 'knn_n_neighbors': 16, 'knn_weights': 'uniform', 'knn_p': 2}. Best is trial 14 with value: 0.9789473684210526.
# [I 2025-09-29 10:54:49,927] Trial 49 finished with value: 0.968421052631579 and parameters: {'model': 'logreg', 'logreg_C': 39.487735989225854, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 595}. Best is trial 14 with value: 0.9789473684210526.
# Best value (CV accuracy): 0.9789473684210526
# Best params: {'model': 'logreg', 'logreg_C': 15.01044022162816, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 775}
#
# Holdout validation accuracy: 1.0
#
# Classification report:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         9
# Iris-versicolor       1.00      1.00      1.00         8
#  Iris-virginica       1.00      1.00      1.00         7
#
#        accuracy                           1.00        24
#       macro avg       1.00      1.00      1.00        24
#    weighted avg       1.00      1.00      1.00        24
