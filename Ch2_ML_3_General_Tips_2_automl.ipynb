# %% [markdown]
# # AutoML

# %% [markdown]
# # Pycaret
# https://jaylala.tistory.com/entry/머신러닝-with-파이썬-Pycaret이란-Pycaret을-활용한-머신러닝
# https://pycaret.gitbook.io/docs

# %% [markdown]
# !pip install pycaret

# %% [markdown]
# ### venv 또는 uv 를 활용한 가상환경 구축 권장
# (Conda 사용시 환경 충돌 발생)
#
# #### venv 셋업
# python3.11 -m venv .venv
# source .venv/bin/activate
# pip install pycaret xgboost seaborn ipykernel
# !pip install pycaret
#
# #### uv 셋업 (권장)
# (powershell 실행)
# Set-ExecutionPolicy RemoteSigned -Scope CurrentUser
# irm https://astral.sh/uv/install.ps1 | iex
#
# (cmd 실행)
# set Path=C:\Users\User\.local\bin;%Path%
# uv init --python 3.11
# uv add --no-build-isolation pycaret xgboost seaborn ipykernel
# .venv\Scripts\activate.bat

# %%
from pycaret.datasets import get_data
from pycaret.classification import *

# %%
# Iris 내장 데이터 로드
data=get_data('iris')
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
from sklearn.model_selection import train_test_split # datasplit

# %%
# 데이터 나눔
from sklearn.model_selection import train_test_split # datasplit
test_size = 0.2
data_train, data_test = train_test_split(data, test_size=test_size)

# %%
# setup 함수는 Pycaret에서 사용되는 데이터 전처리 및 모델 학습 설정을 수행합니다.
# 데이터 전처리와 모델 학습 설정
exp = setup(data_train, target='species')
# Out:
# <style type="text/css">
# #T_3c450_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3c450">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c450_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3c450_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c450_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3c450_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3c450_row0_col1" class="data row0 col1" >7897</td>
#     </tr>
#     <tr>
#       <th id="T_3c450_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3c450_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3c450_row1_col1" class="data row1 col1" >species</td>
#     </tr>
#     <tr>
#       <th id="T_3c450_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3c450_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_3c450_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_3c450_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3c450_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_3c450_row3_col1" class="data row3 col1" >Iris-setosa: 0, Iris-versicolor: 1, Iris-virginica: 2</td>
#     </tr>
#     <tr>
#       <th id="T_3c450_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3c450_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_3c450_row4_col1" class="data row4 col1" >(120, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_3c450_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3c450_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_3c450_row5_col1" class="data row5 col1" >(120, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_3c450_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3c450_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_3c450_row6_col1" class="data row6 col1" >(84, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_3c450_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3c450_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_3c450_row7_col1" class="data row7 col1" >(36, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_3c450_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3c450_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_3c450_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_3c450_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3c450_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_3c450_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3c450_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3c450_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_3c450_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_3c450_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3c450_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_3c450_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_3c450_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3c450_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_3c450_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_3c450_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3c450_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_3c450_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_3c450_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3c450_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_3c450_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_3c450_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3c450_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_3c450_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_3c450_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3c450_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_3c450_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3c450_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3c450_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_3c450_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3c450_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3c450_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_3c450_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_3c450_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_3c450_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_3c450_row19_col1" class="data row19 col1" >18fc</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Setup 함수설명
#
# - session_id: 각 실험에 대한 고유한 세션 ID, 이 값은 실험을 추적하고 관리하는데 사용되는 값으로, 임의로 생성
#
# - Target : 목표 변수(타겟)
#
# - Target Type: 목표 변수 (타겟)의 데이터 타입, 자동으로 감지
#
# - Target Mapping : 목표 변수의 종류를 알려줍니다.
#   목표 변수는 setosa, versicolor, virginica 이며, 각 변수들은 분석간 0 / 1 / 2 로 벡터화됨을 의미합니다.
#
# - Original Data Shape: 원본 데이터의 형태, 즉 행과 열의 수를 나타내는 정보
#
# - Transformed Data Shape : 데이터 전처리 후 결과
#
# - Transformed train set shape : 전처리 된 데이터를 학습 데이터로 나눈 결과
#
# - Transformed test set shape : 전처리 된 데이터를 테스트 데이터로 나눈 결과
#
# - Numeric Features  : 데이터셋에서 숫자로 표현된 독립변수 개수
#
# - Preprocess : setup 함수에서 진행한 전처리(Preprocess)여부. 전처리는 1) 결측값 처리, 2) 범주형 변수 인코딩, 3) 데이터 분할(학습 / 테스트), 4) 스케일링(표준화 또는 정규화)
#
# - Imputation type : 결측값을 어떻게 처리할 지
#
# - Numeric Imputation : 숫자형 데이터의 결측값 처리방법
#
# - Categorical Imputation : 범주형 데이터의 결측값 처리 방법
#
# - Fold Generator : k-fold CV를 위해 fold를 만들때 fold를 나누는 방법
#
# - Fold Number : fold의 개수
#
# - cpu_jobs : 병렬 처리에 사용되는 CPU 코어의 개수
#  -1: 시스템에서 사용할 수 있는 모든 CPU를 사용
#
# - Use GPU : GPU를 사용했는지 여부
#
# - Log Experiment : 실험 결과를 로그에 기록하고 관리할지
#
# - Experiment Name : 실험 이름
#
# 출처: https://jaylala.tistory.com/entry/머신러닝-with-파이썬-Pycaret이란-Pycaret을-활용한-머신러닝

# %%
# 모델 비교
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_664f6 th {
#   text-align: left;
# }
# #T_664f6_row0_col0, #T_664f6_row0_col2, #T_664f6_row1_col0, #T_664f6_row1_col1, #T_664f6_row1_col2, #T_664f6_row1_col3, #T_664f6_row1_col4, #T_664f6_row1_col5, #T_664f6_row1_col6, #T_664f6_row1_col7, #T_664f6_row2_col0, #T_664f6_row2_col1, #T_664f6_row2_col2, #T_664f6_row2_col3, #T_664f6_row2_col4, #T_664f6_row2_col5, #T_664f6_row2_col6, #T_664f6_row2_col7, #T_664f6_row3_col0, #T_664f6_row3_col1, #T_664f6_row3_col2, #T_664f6_row3_col3, #T_664f6_row3_col4, #T_664f6_row3_col5, #T_664f6_row3_col6, #T_664f6_row3_col7, #T_664f6_row4_col0, #T_664f6_row4_col1, #T_664f6_row4_col2, #T_664f6_row4_col3, #T_664f6_row4_col4, #T_664f6_row4_col5, #T_664f6_row4_col6, #T_664f6_row4_col7, #T_664f6_row5_col0, #T_664f6_row5_col1, #T_664f6_row5_col2, #T_664f6_row5_col3, #T_664f6_row5_col4, #T_664f6_row5_col5, #T_664f6_row5_col6, #T_664f6_row5_col7, #T_664f6_row6_col0, #T_664f6_row6_col1, #T_664f6_row6_col2, #T_664f6_row6_col3, #T_664f6_row6_col4, #T_664f6_row6_col5, #T_664f6_row6_col6, #T_664f6_row6_col7, #T_664f6_row7_col0, #T_664f6_row7_col1, #T_664f6_row7_col3, #T_664f6_row7_col4, #T_664f6_row7_col5, #T_664f6_row7_col6, #T_664f6_row7_col7, #T_664f6_row8_col0, #T_664f6_row8_col1, #T_664f6_row8_col3, #T_664f6_row8_col4, #T_664f6_row8_col5, #T_664f6_row8_col6, #T_664f6_row8_col7, #T_664f6_row9_col0, #T_664f6_row9_col1, #T_664f6_row9_col2, #T_664f6_row9_col3, #T_664f6_row9_col4, #T_664f6_row9_col5, #T_664f6_row9_col6, #T_664f6_row9_col7, #T_664f6_row10_col0, #T_664f6_row10_col1, #T_664f6_row10_col3, #T_664f6_row10_col4, #T_664f6_row10_col5, #T_664f6_row10_col6, #T_664f6_row10_col7, #T_664f6_row11_col0, #T_664f6_row11_col1, #T_664f6_row11_col2, #T_664f6_row11_col3, #T_664f6_row11_col4, #T_664f6_row11_col5, #T_664f6_row11_col6, #T_664f6_row11_col7, #T_664f6_row12_col0, #T_664f6_row12_col1, #T_664f6_row12_col2, #T_664f6_row12_col3, #T_664f6_row12_col4, #T_664f6_row12_col5, #T_664f6_row12_col6, #T_664f6_row12_col7, #T_664f6_row13_col0, #T_664f6_row13_col1, #T_664f6_row13_col2, #T_664f6_row13_col3, #T_664f6_row13_col4, #T_664f6_row13_col5, #T_664f6_row13_col6, #T_664f6_row13_col7, #T_664f6_row14_col0, #T_664f6_row14_col1, #T_664f6_row14_col2, #T_664f6_row14_col3, #T_664f6_row14_col4, #T_664f6_row14_col5, #T_664f6_row14_col6, #T_664f6_row14_col7 {
_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_78c1b_row11_col0" class="data row11 col0" >0.0473</td>
#       <td id="T_78c1b_row11_col1" class="data row11 col1" >0.0056</td>
#       <td id="T_78c1b_row11_col2" class="data row11 col2" >0.0473</td>
#       <td id="T_78c1b_row11_col3" class="data row11 col3" >0.0355</td>
#       <td id="T_78c1b_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
# 모델 평가
evaluate_model(tuned_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# 예측을 위한 test data
test_data = data_test

# %%
# 예측 수행
pred = predict_model(tuned_model, data=test_data)
# Out:
# <style type="text/css">
# </style>
# <table id="T_03eff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03eff_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_03eff_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_03eff_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_03eff_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_03eff_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_03eff_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_03eff_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_03eff_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03eff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_03eff_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_03eff_row0_col1" class="data row0 col1" >0.9667</td>
#       <td id="T_03eff_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_03eff_row0_col3" class="data row0 col3" >0.9667</td>
#       <td id="T_03eff_row0_col4" class="data row0 col4" >0.9708</td>
#       <td id="T_03eff_row0_col5" class="data row0 col5" >0.9671</td>
#       <td id="T_03eff_row0_col6" class="data row0 col6" >0.9490</td>
#       <td id="T_03eff_row0_col7" class="data row0 col7" >0.9506</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 단일 모델만 선택해서 학습
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# knn       sklearn.neighbors._classification.KNeighborsCl...   True
# nb                           sklearn.naive_bayes.GaussianNB   True
# dt             sklearn.tree._classes.DecisionTreeClassifier   True
# svm       sklearn.linear_model._stochastic_gradient.SGDC...   True
# rbfsvm                             sklearn.svm._classes.SVC  False
# gpc       sklearn.gaussian_process._gpc.GaussianProcessC...  False
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# ridge           sklearn.linear_model._ridge.RidgeClassifier   True
# rf          sklearn.ensemble._forest.RandomForestClassifier   True
# qda       sklearn.discriminant_analysis.QuadraticDiscrim...   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostClas...   True
# gbc         sklearn.ensemble._gb.GradientBoostingClassifier   True
# lda       sklearn.discriminant_analysis.LinearDiscrimina...   True
# et            sklearn.ensemble._forest.ExtraTreesClassifier   True
# xgboost                       xgboost.sklearn.XGBClassifier   True
# lightgbm                    lightgbm.sklearn.LGBMClassifier   True
# dummy                         sklearn.dummy.DummyClassifier   True

# %%
select_model = create_model('rf')
tuned_model = tune_model(select_model)
# Out:
# <style type="text/css">
# #T_a8d88_row10_col0, #T_a8d88_row10_col1, #T_a8d88_row10_col2, #T_a8d88_row10_col3, #T_a8d88_row10_col4, #T_a8d88_row10_col5, #T_a8d88_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a8d88">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8d88_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a8d88_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a8d88_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a8d88_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a8d88_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_a8d88_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_a8d88_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8d88_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8d88_row0_col0" class="data row0 col0" >0.8889</td>
#       <td id="T_a8d88_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_a8d88_row0_col2" class="data row0 col2" >0.8889</td>
#       <td id="T_a8d88_row0_col3" class="data row0 col3" >0.9167</td>
#       <td id="T_a8d88_row0_col4" class="data row0 col4" >0.8857</td>
#       <td id="T_a8d88_row0_col5" class="data row0 col5" >0.8333</td>
#       <td id="T_a8d88_row0_col6" class="data row0 col6" >0.8492</td>
#     </tr>
#     <tr>
#       <th id="T_a8d88_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a8d88_row1_col0" class="data row1 col0" >0.8889</td>
#       <td id="T_a8d88_row1_col1" class="data row1 col1" >1.0000</td>
#       <td id="T_a8d88_row1_col2" class="data row1 col2" >0.8889</td>
#       <td id="T_a8d88_row1_col3" class="data row1 col3" >0.9167</td>
#       <td id="T_a8d88_row1_col4" class="data row1 col4" >0.8857</td>
#       <td id="T_a8d88_row1_col5" class="data row1 col5" >0.8333</td>
#       <td id="T_a8d88_row1_col6" class="data row1 col6" >0.8492</td>
#     </tr>
#     <tr>
#       <th id="T_a8d88_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a8d88_row2_col0" class="data row2 col0" >1.0000</td>
#       <td id="T_a8d88_row2_col1" class="data row2 col1" >1.0000</td>
#       <td id="T_a8d88_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_a8d88_row2_col3" class="data row2 col3" >1.0000</td>
#       <td id="T_a8d88_row2_col4" class="data row2 col4" >1.0000</td>
#       <td id="T_a8d88_row2_col5" class="data row2 col5" >1.0000</td>
#       <td id="T_a8d88_row2_col6" class="data row2 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a8d88_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a8d88_row3_col0" class="data row3 col0" >0.8889</td>
#       <td id="T_a8d88_row3_col1" class="data row3 col1" >1.0000</td>
#       <td id="T_a8d88_row3_col2" class="data row3 col2" >0.8889</td>
#       <td id="T_a8d88_row3_col3" class="data row3 col3" >0.9167</td>
#       <td id="T_a8d88_row3_col4" class="data row3 col4" >0.8857</td>
#       <td id="T_a8d88_row3_col5" class="data row3 col5" >0.8333</td>
#       <td id="T_a8d88_row3_col6" class="data row3 col6" >0.8492</td>
#     </tr>
#     <tr>
#       <th id="T_a8d88_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a8d88_row4_col0" class="data row4 col0" >1.0000</td>
#       <td id="T_a8d88_row4_col1" class="data row4 col1" >1.0000</td>
#       <td id="T_a8d88_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_a8d88_row4_col3" class="data row4 col3" >1.0000</td>
#       <td id="T_a8d88_row4_col4" class="data row4 col4" >1.0000</td>
#       <td id="T_a8d88_row4_col5" class="data row4 col5" >1.0000</td>
#       <td id="T_a8d88_row4_col6" class="data row4 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a8d88_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a8d88_row5_col0" class="data row5 col0" >1.0000</td>
#       <td id="T_a8d88_row5_col1" class="data row5 col1" >1.0000</td>
#       <td id="T_a8d88_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_a8d88_row5_col3" class="data row5 col3" >1.0000</td>
#       <td id="T_a8d88_row5_col4" class="data row5 col4" >1.0000</td>
#       <td id="T_a8d88_row5_col5" class="data row5 col5" >1.0000</td>
#       <td id="T_a8d88_row5_col6" class="data row5 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a8d88_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a8d88_row6_col0" class="data row6 col0" >1.0000</td>
#       <td id="T_a8d88_row6_col1" class="data row6 col1" >1.0000</td>
#       <td id="T_a8d88_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_a8d88_row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_a8d88_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_a8d88_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_a8d88_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a8d88_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a8d88_row7_col0" class="data row7 col0" >1.0000</td>
#       <td id="T_a8d88_row7_col1" class="data row7 col1" >1.0000</td>
#       <td id="T_a8d88_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_a8d88_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_a8d88_row7_col4" class="data row7 col4" >1.0000</td>
#       <td id="T_a8d88_row7_col5" class="data row7 col5" >1.0000</td>
#       <td id="T_a8d88_row7_col6" class="data row7 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a8d88_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a8d88_row8_col0" class="data row8 col0" >0.8750</td>
#       <td id="T_a8d88_row8_col1" class="data row8 col1" >1.0000</td>
#       <td id="T_a8d88_row8_col2" class="data row8 col2" >0.8750</td>
#       <td id="T_a8d88_row8_col3" class="data row8 col3" >0.9062</td>
#       <td id="T_a8d88_row8_col4" class="data row8 col4" >0.8714</td>
#       <td id="T_a8d88_row8_col5" class="data row8 col5" >0.8095</td>
#       <td id="T_a8d88_row8_col6" class="data row8 col6" >0.8295</td>
#     </tr>
#     <tr>
#       <th id="T_a8d88_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a8d88_row9_col0" class="data row9 col0" >1.0000</td>
#       <td id="T_a8d88_row9_col1" class="data row9 col1" >1.0000</td>
#       <td id="T_a8d88_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_a8d88_row9_col3" class="data row9 col3" >1.0000</td>
#       <td id="T_a8d88_row9_col4" class="data row9 col4" >1.0000</td>
#       <td id="T_a8d88_row9_col5" class="data row9 col5" >1.0000</td>
#       <td id="T_a8d88_row9_col6" class="data row9 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_a8d88_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_a8d88_row10_col0" class="data row10 col0" >0.9542</td>
#       <td id="T_a8d88_row10_col1" class="data row10 col1" >1.0000</td>
#       <td id="T
row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_d25d3_row11_col2" class="data row11 col2" >0.0509</td>
#       <td id="T_d25d3_row11_col3" class="data row11 col3" >0.0382</td>
#       <td id="T_d25d3_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
evaluate_model(tuned_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# # OPTUNA

# %%
import optuna

def objective(trial):
    x = trial.suggest_float('x', -10, 10)
    return (x - 2) ** 2

study = optuna.create_study()
study.optimize(objective, n_trials=50)

study.best_params
# Out:
# [I 2025-09-08 21:58:43,088] A new study created in memory with name: no-name-90a09808-caa0-45ba-98fe-ea74d9b41a1a
# [I 2025-09-08 21:58:43,089] Trial 0 finished with value: 34.12630298057828 and parameters: {'x': -3.8417722465514075}. Best is trial 0 with value: 34.12630298057828.
# [I 2025-09-08 21:58:43,090] Trial 1 finished with value: 96.81086014250523 and parameters: {'x': -7.839250994994753}. Best is trial 0 with value: 34.12630298057828.
# [I 2025-09-08 21:58:43,091] Trial 2 finished with value: 69.12769299841638 and parameters: {'x': -6.314306525406456}. Best is trial 0 with value: 34.12630298057828.
# [I 2025-09-08 21:58:43,092] Trial 3 finished with value: 1.1702837570689613 and parameters: {'x': 0.9182034585611945}. Best is trial 3 with value: 1.1702837570689613.
# [I 2025-09-08 21:58:43,092] Trial 4 finished with value: 35.48688808954394 and parameters: {'x': -3.9570872152037477}. Best is trial 3 with value: 1.1702837570689613.
# [I 2025-09-08 21:58:43,092] Trial 5 finished with value: 0.3272445844457244 and parameters: {'x': 2.5720529559802348}. Best is trial 5 with value: 0.3272445844457244.
# [I 2025-09-08 21:58:43,093] Trial 6 finished with value: 11.99748376748517 and parameters: {'x': 5.463738409217008}. Best is trial 5 with value: 0.3272445844457244.
# [I 2025-09-08 21:58:43,094] Trial 7 finished with value: 124.19600192778536 and parameters: {'x': -9.14432599701684}. Best is trial 5 with value: 0.3272445844457244.
# [I 2025-09-08 21:58:43,094] Trial 8 finished with value: 13.785616961433648 and parameters: {'x': 5.712898727602687}. Best is trial 5 with value: 0.3272445844457244.
# [I 2025-09-08 21:58:43,094] Trial 9 finished with value: 22.67786204092583 and parameters: {'x': 6.762127890022047}. Best is trial 5 with value: 0.3272445844457244.
# [I 2025-09-08 21:58:43,097] Trial 10 finished with value: 0.7772196574020684 and parameters: {'x': 1.1183993776079395}. Best is trial 5 with value: 0.3272445844457244.
# [I 2025-09-08 21:58:43,098] Trial 11 finished with value: 0.10238399477768532 and parameters: {'x': 1.6800250091371431}. Best is trial 11 with value: 0.10238399477768532.
# [I 2025-09-08 21:58:43,089] Trial 0 finished with value: 34.12630298057828 and parameters: {'x': -3.8417722465514075}. Best is trial 0 with value: 34.12630298057828.
# [I 2025-09-08 21:58:43,090] Trial 1 finished with value: 96.81086014250523 and parameters: {'x': -7.839250994994753}. Best is trial 0 with value: 34.12630298057828.
# [I 2025-09-08 21:58:43,091] Trial 2 finished with value: 69.12769299841638 and parameters: {'x': -6.314306525406456}. Best is trial 0 with value: 34.12630298057828.
# [I 2025-09-08 21:58:43,092] Trial 3 finished with value: 1.1702837570689613 and parameters: {'x': 0.9182034585611945}. Best is trial 3 with value: 1.1702837570689613.
# [I 2025-09-08 21:58:43,092] Trial 4 finished with value: 35.48688808954394 and parameters: {'x': -3.9570872152037477}. Best is trial 3 with value: 1.1702837570689613.
# [I 2025-09-08 21:58:43,092] Trial 5 finished with value: 0.3272445844457244 and parameters: {'x': 2.5720529559802348}. Best is trial 5 with value: 0.3272445844457244.
# [I 2025-09-08 21:58:43,093] Trial 6 finished with value: 11.99748376748517 and parameters: {'x': 5.463738409217008}. Best is trial 5 with value: 0.3272445844457244.
# [I 2025-09-08 21:58:43,094] Trial 7 finished with value: 124.19600192778536 and parameters: {'x': -9.14432599701684}. Best is trial 5 with value: 0.3272445844457244.
# [I 2025-09-08 21:58:43,094] Trial 8 finished with value: 13.785616961433648 and parameters: {'x': 5.712898727602687}. Best is trial 5 with value: 0.3272445844457244.
# [I 2025-09-08 21:58:43,094] Trial 9 finished with value: 22.67786204092583 and parameters: {'x': 6.762127890022047}. Best is trial 5 with value: 0.3272445844457244.
# [I 2025-09-08 21:58:43,097] Trial 10 finished with value: 0.7772196574020684 and parameters: {'x': 1.1183993776079395}. Best is trial 5 with value: 0.3272445844457244.
# [I 2025-09-08 21:58:43,098] Trial 11 finished with value: 0.10238399477768532 and parameters: {'x': 1.6800250091371431}. Best is trial 11 with value: 0.10238399477768532.
# [I 2025-09-08 21:58:43,100] Trial 12 finished with value: 61.16018665784493 and parameters: {'x': 9.820497852301024}. Best is trial 11 with value: 0.10238399477768532.
# [I 2025-09-08 21:58:43
. Best is trial 46 with value: 3.9477304059816514e-07.
# [I 2025-09-08 21:58:43,151] Trial 47 finished with value: 142.1335854331796 and parameters: {'x': -9.921979090452206}. Best is trial 46 with value: 3.9477304059816514e-07.
# [I 2025-09-08 21:58:43,154] Trial 48 finished with value: 4.444270127821928 and parameters: {'x': 4.108143763556444}. Best is trial 46 with value: 3.9477304059816514e-07.
# [I 2025-09-08 21:58:43,155] Trial 49 finished with value: 75.09710453045876 and parameters: {'x': -6.665858557030502}. Best is trial 46 with value: 3.9477304059816514e-07.
# [I 2025-09-08 21:58:43,149] Trial 46 finished with value: 3.9477304059816514e-07 and parameters: {'x': 2.0006283096693496}. Best is trial 46 with value: 3.9477304059816514e-07.
# [I 2025-09-08 21:58:43,151] Trial 47 finished with value: 142.1335854331796 and parameters: {'x': -9.921979090452206}. Best is trial 46 with value: 3.9477304059816514e-07.
# [I 2025-09-08 21:58:43,154] Trial 48 finished with value: 4.444270127821928 and parameters: {'x': 4.108143763556444}. Best is trial 46 with value: 3.9477304059816514e-07.
# [I 2025-09-08 21:58:43,155] Trial 49 finished with value: 75.09710453045876 and parameters: {'x': -6.665858557030502}. Best is trial 46 with value: 3.9477304059816514e-07.
# {'x': 2.0006283096693496}

# %% [markdown]
# # Optuna로 data_train 기반 모델/하이퍼파라미터 탐색
# - 목적: data_train에서 교차검증 정확도를 최대화하는 모델과 파라미터 찾기
# - 대상 모델: LogisticRegression, RandomForest, SVC, KNN
# - 평가: Stratified 5-Fold Accuracy

# %%
# --- 1) Imports & helpers
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold, cross_val_score, train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
import optuna

# --- 2) Prepare X, y from data_train

X = data_train.drop(columns=['species'])
y = data_train['species']

# train/validation split for final holdout test (optional)
X_tr, X_val, y_tr, y_val = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# --- 3) Define search space and objective
MODEL_CHOICES = ['logreg', 'rf', 'svc', 'knn']

def make_pipeline(trial, model_key):
    scaler = StandardScaler()

    if model_key == 'logreg':
        C = trial.suggest_float('logreg_C', 1e-3, 1e3, log=True)
        solver = trial.suggest_categorical('logreg_solver', ['lbfgs', 'liblinear'])
        max_iter = trial.suggest_int('logreg_max_iter', 200, 1000)
        clf = LogisticRegression(C=C, solver=solver, max_iter=max_iter, n_jobs=None)
    elif model_key == 'rf':
        n_estimators = trial.suggest_int('rf_n_estimators', 50, 400)
        max_depth = trial.suggest_int('rf_max_depth', 2, 20)
        min_samples_split = trial.suggest_int('rf_min_samples_split', 2, 10)
        min_samples_leaf = trial.suggest_int('rf_min_samples_leaf', 1, 5)
        clf = RandomForestClassifier(
            n_estimators=n_estimators,
            max_depth=max_depth,
            min_samples_split=min_samples_split,
            min_samples_leaf=min_samples_leaf,
            random_state=42,
        )
    elif model_key == 'svc':
        C = trial.suggest_float('svc_C', 1e-3, 1e3, log=True)
        gamma = trial.suggest_float('svc_gamma', 1e-4, 1e0, log=True)
        kernel = trial.suggest_categorical('svc_kernel', ['rbf', 'poly'])
        degree = 3 if kernel != 'poly' else trial.suggest_int('svc_degree', 2, 5)
        clf = SVC(C=C, gamma=gamma, kernel=kernel, degree=degree)
    elif model_key == 'knn':
        n_neighbors = trial.suggest_int('knn_n_neighbors', 1, 30)
        weights = trial.suggest_categorical('knn_weights', ['uniform', 'distance'])
        p = trial.suggest_int('knn_p', 1, 2)  # 1=Manhattan, 2=Euclidean
        clf = KNeighborsClassifier(n_neighbors=n_neighbors, weights=weights, p=p)
    else:
        raise ValueError(f"Unknown model key: {model_key}")

    return Pipeline([
        ('scaler', scaler),
        ('clf', clf)
    ])


def objective(trial):
    model_key = trial.suggest_categorical('model', MODEL_CHOICES)
    pipe = make_pipeline(trial, model_key)

    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(pipe, X_tr, y_tr, cv=cv, scoring='accuracy', n_jobs=None)
    return scores.mean()

# --- 4) Run study
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50, show_progress_bar=False)

print('Best value (CV accuracy):', study.best_value)
print('Best params:', study.best_params)

# --- 5) Refit best pipeline on the full training split, evaluate on validation
best_model_key = study.best_params['model']
best_pipe = make_pipeline(study.best_trial, best_model_key)
best_pipe.fit(X_tr, y_tr)

val_pred = best_pipe.predict(X_val)
val_acc = accuracy_score(y_val, val_pred)
print('\nHoldout validation accuracy:', val_acc)
print('\nClassification report:\n', classification_report(y_val, val_pred))

# best_pipe은 이후 전체 data_train으로 재학습하여 최종 모델로 사용할 수 있습니다.
# best_pipe.fit(X, y)
# Out:
# [I 2025-09-08 21:58:43,175] A new study created in memory with name: no-name-ba6ffec2-d9fc-43e5-a307-e3b955cddb62
# [I 2025-09-08 21:58:43,930] Trial 0 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 340, 'rf_max_depth': 9, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 4}. Best is trial 0 with value: 0.9689473684210526.
# [I 2025-09-08 21:58:43,930] Trial 0 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 340, 'rf_max_depth': 9, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 4}. Best is trial 0 with value: 0.9689473684210526.
# [I 2025-09-08 21:58:43,944] Trial 1 finished with value: 0.9278947368421052 and parameters: {'model': 'knn', 'knn_n_neighbors': 28, 'knn_weights': 'uniform', 'knn_p': 1}. Best is trial 0 with value: 0.9689473684210526.
# [I 2025-09-08 21:58:43,944] Trial 1 finished with value: 0.9278947368421052 and parameters: {'model': 'knn', 'knn_n_neighbors': 28, 'knn_weights': 'uniform', 'knn_p': 1}. Best is trial 0 with value: 0.9689473684210526.
# [I 2025-09-08 21:58:44,138] Trial 2 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 88, 'rf_max_depth': 14, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:44,149] Trial 3 finished with value: 0.948421052631579 and parameters: {'model': 'knn', 'knn_n_neighbors': 13, 'knn_weights': 'distance', 'knn_p': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:44,138] Trial 2 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 88, 'rf_max_depth': 14, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:44,149] Trial 3 finished with value: 0.948421052631579 and parameters: {'model': 'knn', 'knn_n_neighbors': 13, 'knn_weights': 'distance', 'knn_p': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:44,163] Trial 4 finished with value: 0.958421052631579 and parameters: {'model': 'knn', 'knn_n_neighbors': 4, 'knn_weights': 'uniform', 'knn_p': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:44,173] Trial 5 finished with value: 0.8757894736842106 and parameters: {'model': 'logreg', 'logreg_C': 0.1795979277974401, 'logreg_solver': 'liblinear', 'logreg_max_iter': 313}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:44,163] Trial 4 finished with value: 0.958421052631579 and parameters: {'model': 'knn', 'knn_n_neighbors': 4, 'knn_weights': 'uniform', 'knn_p': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:44,173] Trial 5 finished with value: 0.8757894736842106 and parameters: {'model': 'logreg', 'logreg_C': 0.1795979277974401, 'logreg_solver': 'liblinear', 'logreg_max_iter': 313}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:44,184] Trial 6 finished with value: 0.3542105263157895 and parameters: {'model': 'svc', 'svc_C': 166.0273923991404, 'svc_gamma': 0.007773687198430968, 'svc_kernel': 'poly', 'svc_degree': 5}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:44,184] Trial 6 finished with value: 0.3542105263157895 and parameters: {'model': 'svc', 'svc_C': 166.0273923991404, 'svc_gamma': 0.007773687198430968, 'svc_kernel': 'poly', 'svc_degree': 5}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:44,479] Trial 7 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 136, 'rf_max_depth': 2, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 4}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:44,490] Trial 8 finished with value: 0.9589473684210527 and parameters: {'model': 'svc', 'svc_C': 4.352274947844486, 'svc_gamma': 0.23228801874060398, 'svc_kernel': 'rbf'}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:44,479] Trial 7 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 136, 'rf_max_depth': 2, 'rf_min_samples_split': 6, 'rf_min_samples_leaf': 4}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:44,490] Trial 8 finished with value: 0.9589473684210527 and parameters: {'model': 'svc', 'svc_C': 4.352274947844486, 'svc_gamma': 0.23228801874060398, 'svc_kernel': 'rbf'}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:44,501] Trial 9 finished with value: 0.9173684210526316 and parameters: {'model': 'logreg', 'logreg_C': 2.1745003345261877, 'logreg_solver': 'liblinear', 'logreg_max_iter': 958}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:44,501] Trial 9 finished with value: 0.9173684210526316 and parameters: {'model': 'logreg', 'logreg_C': 2.1745003345261877, 'logreg_solver': 'liblinear', 'logreg_max_iter': 958}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:44,663] Trial 10 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 72, 'rf_max_depth': 20, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:44,663] Trial 10 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 72, 'rf_max_depth': 20, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:44,785] Trial 11 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 51, 'rf_max_depth': 20, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:44,785] Trial 11 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 51, 'rf_max_depth': 20, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:44,938] Trial 12 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 67, 'rf_max_depth': 19, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:44,938] Trial 12 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 67, 'rf_max_depth': 19, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:45,358] Trial 13 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 196, 'rf_max_depth': 14, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 2}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:45,358] Trial 13 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 196, 'rf_max_depth': 14, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 2}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:45,671] Trial 14 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 145, 'rf_max_depth': 14, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 2}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:45,671] Trial 14 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 145, 'rf_max_depth': 14, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 2}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:46,300] Trial 15 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 290, 'rf_max_depth': 15, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:46,300] Trial 15 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 290, 'rf_max_depth': 15, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:46,549] Trial 16 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 114, 'rf_max_depth': 7, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 2}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:46,563] Trial 17 finished with value: 0.3542105263157895 and parameters: {'model': 'svc', 'svc_C': 0.001916483153135514, 'svc_gamma': 0.0001010351197948923, 'svc_kernel': 'rbf'}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:46,549] Trial 16 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 114, 'rf_max_depth': 7, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 2}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:46,563] Trial 17 finished with value: 0.3542105263157895 and parameters: {'model': 'svc', 'svc_C': 0.001916483153135514, 'svc_gamma': 0.0001010351197948923, 'svc_kernel': 'rbf'}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:46,581] Trial 18 finished with value: 0.958421052631579 and parameters: {'model': 'logreg', 'logreg_C': 696.1515060613523, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 784}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:46,581] Trial 18 finished with value: 0.958421052631579 and parameters: {'model': 'logreg', 'logreg_C': 696.1515060613523, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 784}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:47,116] Trial 19 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 252, 'rf_max_depth': 18, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 3}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:47,116] Trial 19 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 252, 'rf_max_depth': 18, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 3}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:47,489] Trial 20 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 173, 'rf_max_depth': 16, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 5}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:47,489] Trial 20 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 173, 'rf_max_depth': 16, 'rf_min_samples_split': 9, 'rf_min_samples_leaf': 5}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:47,617] Trial 21 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 55, 'rf_max_depth': 20, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:47,617] Trial 21 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 55, 'rf_max_depth': 20, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:47,818] Trial 22 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 89, 'rf_max_depth': 20, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:47,818] Trial 22 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 89, 'rf_max_depth': 20, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:47,939] Trial 23 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 51, 'rf_max_depth': 17, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 2}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:47,939] Trial 23 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 51, 'rf_max_depth': 17, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 2}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:48,175] Trial 24 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 108, 'rf_max_depth': 10, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:48,175] Trial 24 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 108, 'rf_max_depth': 10, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:48,390] Trial 25 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 96, 'rf_max_depth': 13, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 2}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:48,403] Trial 26 finished with value: 0.938421052631579 and parameters: {'model': 'knn', 'knn_n_neighbors': 30, 'knn_weights': 'distance', 'knn_p': 2}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:48,390] Trial 25 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 96, 'rf_max_depth': 13, 'rf_min_samples_split': 5, 'rf_min_samples_leaf': 2}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:48,403] Trial 26 finished with value: 0.938421052631579 and parameters: {'model': 'knn', 'knn_n_neighbors': 30, 'knn_weights': 'distance', 'knn_p': 2}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:48,418] Trial 27 finished with value: 0.3542105263157895 and parameters: {'model': 'svc', 'svc_C': 0.0018151595250045516, 'svc_gamma': 0.5859087606307382, 'svc_kernel': 'poly', 'svc_degree': 2}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:48,433] Trial 28 finished with value: 0.7189473684210526 and parameters: {'model': 'logreg', 'logreg_C': 0.0012241007270631919, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 206}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:48,418] Trial 27 finished with value: 0.3542105263157895 and parameters: {'model': 'svc', 'svc_C': 0.0018151595250045516, 'svc_gamma': 0.5859087606307382, 'svc_kernel': 'poly', 'svc_degree': 2}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:48,433] Trial 28 finished with value: 0.7189473684210526 and parameters: {'model': 'logreg', 'logreg_C': 0.0012241007270631919, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 206}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:49,268] Trial 29 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 400, 'rf_max_depth': 17, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:49,268] Trial 29 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 400, 'rf_max_depth': 17, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:49,592] Trial 30 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 151, 'rf_max_depth': 12, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 3}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:49,592] Trial 30 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 151, 'rf_max_depth': 12, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 3}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:49,715] Trial 31 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 51, 'rf_max_depth': 20, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:49,715] Trial 31 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 51, 'rf_max_depth': 20, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:49,906] Trial 32 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 84, 'rf_max_depth': 18, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:49,906] Trial 32 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 84, 'rf_max_depth': 18, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:50,084] Trial 33 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 79, 'rf_max_depth': 20, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:50,098] Trial 34 finished with value: 0.9484210526315788 and parameters: {'model': 'knn', 'knn_n_neighbors': 2, 'knn_weights': 'distance', 'knn_p': 2}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:50,084] Trial 33 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 79, 'rf_max_depth': 20, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:50,098] Trial 34 finished with value: 0.9484210526315788 and parameters: {'model': 'knn', 'knn_n_neighbors': 2, 'knn_weights': 'distance', 'knn_p': 2}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:50,356] Trial 35 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 118, 'rf_max_depth': 18, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 2}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:50,372] Trial 36 finished with value: 0.938421052631579 and parameters: {'model': 'knn', 'knn_n_neighbors': 20, 'knn_weights': 'uniform', 'knn_p': 2}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:50,356] Trial 35 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 118, 'rf_max_depth': 18, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 2}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:50,372] Trial 36 finished with value: 0.938421052631579 and parameters: {'model': 'knn', 'knn_n_neighbors': 20, 'knn_weights': 'uniform', 'knn_p': 2}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:50,556] Trial 37 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 81, 'rf_max_depth': 19, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:50,556] Trial 37 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 81, 'rf_max_depth': 19, 'rf_min_samples_split': 4, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:50,570] Trial 38 finished with value: 0.3542105263157895 and parameters: {'model': 'svc', 'svc_C': 773.8725108899799, 'svc_gamma': 0.00011785170241002438, 'svc_kernel': 'poly', 'svc_degree': 5}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:50,582] Trial 39 finished with value: 0.9589473684210527 and parameters: {'model': 'logreg', 'logreg_C': 569.7527844576216, 'logreg_solver': 'liblinear', 'logreg_max_iter': 547}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:50,570] Trial 38 finished with value: 0.3542105263157895 and parameters: {'model': 'svc', 'svc_C': 773.8725108899799, 'svc_gamma': 0.00011785170241002438, 'svc_kernel': 'poly', 'svc_degree': 5}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:50,582] Trial 39 finished with value: 0.9589473684210527 and parameters: {'model': 'logreg', 'logreg_C': 569.7527844576216, 'logreg_solver': 'liblinear', 'logreg_max_iter': 547}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:50,703] Trial 40 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 51, 'rf_max_depth': 16, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:50,703] Trial 40 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 51, 'rf_max_depth': 16, 'rf_min_samples_split': 3, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:51,275] Trial 41 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 274, 'rf_max_depth': 15, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:51,275] Trial 41 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 274, 'rf_max_depth': 15, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:51,955] Trial 42 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 326, 'rf_max_depth': 18, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:51,955] Trial 42 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 326, 'rf_max_depth': 18, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:52,409] Trial 43 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 215, 'rf_max_depth': 16, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 2}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:52,409] Trial 43 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 215, 'rf_max_depth': 16, 'rf_min_samples_split': 7, 'rf_min_samples_leaf': 2}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:53,029] Trial 44 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 300, 'rf_max_depth': 12, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:53,029] Trial 44 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 300, 'rf_max_depth': 12, 'rf_min_samples_split': 10, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:53,202] Trial 45 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 76, 'rf_max_depth': 19, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:53,217] Trial 46 finished with value: 0.948421052631579 and parameters: {'model': 'knn', 'knn_n_neighbors': 12, 'knn_weights': 'uniform', 'knn_p': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:53,202] Trial 45 finished with value: 0.9789473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 76, 'rf_max_depth': 19, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:53,217] Trial 46 finished with value: 0.948421052631579 and parameters: {'model': 'knn', 'knn_n_neighbors': 12, 'knn_weights': 'uniform', 'knn_p': 1}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:53,231] Trial 47 finished with value: 0.3542105263157895 and parameters: {'model': 'svc', 'svc_C': 0.24074100837207418, 'svc_gamma': 0.005734181410250787, 'svc_kernel': 'rbf'}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:53,246] Trial 48 finished with value: 0.8963157894736842 and parameters: {'model': 'logreg', 'logreg_C': 0.003432837866232191, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 525}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:53,231] Trial 47 finished with value: 0.3542105263157895 and parameters: {'model': 'svc', 'svc_C': 0.24074100837207418, 'svc_gamma': 0.005734181410250787, 'svc_kernel': 'rbf'}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:53,246] Trial 48 finished with value: 0.8963157894736842 and parameters: {'model': 'logreg', 'logreg_C': 0.003432837866232191, 'logreg_solver': 'lbfgs', 'logreg_max_iter': 525}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:53,765] Trial 49 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 245, 'rf_max_depth': 15, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 2}. Best is trial 2 with value: 0.9789473684210526.
# [I 2025-09-08 21:58:53,765] Trial 49 finished with value: 0.9689473684210526 and parameters: {'model': 'rf', 'rf_n_estimators': 245, 'rf_max_depth': 15, 'rf_min_samples_split': 8, 'rf_min_samples_leaf': 2}. Best is trial 2 with value: 0.9789473684210526.
# Best value (CV accuracy): 0.9789473684210526
# Best params: {'model': 'rf', 'rf_n_estimators': 88, 'rf_max_depth': 14, 'rf_min_samples_split': 2, 'rf_min_samples_leaf': 1}
#
# Holdout validation accuracy: 0.875
#
# Classification report:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         8
# Iris-versicolor       0.80      0.89      0.84         9
#  Iris-virginica       0.83      0.71      0.77         7
#
#        accuracy                           0.88        24
#       macro avg       0.88      0.87      0.87        24
#    weighted avg       0.88      0.88      0.87        24

# %% [markdown]
# # H2O

# %% [markdown]
# Need to install Java (SDK)

# %%
# H2O AutoML on data_train
# 1) Install/import and init
import h2o
from h2o.automl import H2OAutoML

from sklearn.metrics import accuracy_score, classification_report

# Start/attach to an H2O cluster
h2o.init(max_mem_size='2G')

# 2) Prepare frames
train_hf = h2o.H2OFrame(data_train)
y = 'species'
x = [c for c in train_hf.columns if c != y]
# Ensure classification target is categorical
train_hf[y] = train_hf[y].asfactor()

# Optional test set
test_hf = None
if 'data_test' in globals() and isinstance(data_test, type(data_train)):
    test_hf = h2o.H2OFrame(data_test)
    test_hf[y] = test_hf[y].asfactor()

# 3) Run AutoML
automl = H2OAutoML(
    max_models=20,          # increase for a more exhaustive search
    seed=42,
    nfolds=5,               # internal CV
    sort_metric='AUTO',     # let H2O pick an appropriate metric
    exclude_algos=None,
    verbosity=None
)
automl.train(x=x, y=y, training_frame=train_hf)

# 4) Leaderboard and best model
lb = automl.leaderboard
print("Top models (leaderboard):")
print(lb.head(rows=10))

leader = automl.leader
print("\nBest model:", leader.model_id)

# 5) Evaluate on test (if available), otherwise reuse training perf summary
if test_hf is not None:
    perf = leader.model_performance(test_hf)
    print("\nTest performance (H2O summary):\n", perf)

    # Also compute sklearn-style metrics for convenience
    pred = leader.predict(test_hf).as_data_frame()['predict']
    true = data_test['species']
    acc = accuracy_score(true, pred)
    print(f"\nTest accuracy (sklearn): {acc:.4f}")
    print("\nClassification report (sklearn):\n", classification_report(true, pred))
else:
    perf = leader.model_performance(train_hf)
    print("\nTrain performance (H2O summary):\n", perf)

# Note: When done, you may shutdown H2O with: h2o.shutdown(prompt=False)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321......... not found.
# Attempting to start a local H2O server...
#  not found.
# Attempting to start a local H2O server...
# ---------------------------------------------------------------------------
# H2OConnectionError                        Traceback (most recent call last)
# File d:\Main\00_Research\00_Python\01_AI-ME_Graduate\AI-ME-Practice\.venv\Lib\site-packages\h2o\h2o.py:270, in init(url, ip, port, name, https, cacert, insecure, username, password, cookies, proxy, start_h2o, nthreads, ice_root, log_dir, log_level, max_log_file_size, enable_assertions, max_mem_size, min_mem_size, strict_version_check, ignore_config, extra_classpath, jvm_custom_args, bind_to_localhost, verbose, **kwargs)
#     269 try:
# --> 270     h2oconn = H2OConnection.open(url=url, ip=ip, port=port, name=name, https=https,
#     271                                  verify_ssl_certificates=verify_ssl_certificates, cacert=cacert,
#     272                                  auth=auth, proxy=proxy, cookies=cookies, verbose=verbose,
#     273                                  msgs=("Checking whether there is an H2O instance running at {url}",
#     274                                        "connected.", "not found."),
#     275                                  strict_version_check=svc)
#     276 except H2OConnectionError:
#     277     # Backward compatibility: in init() port parameter really meant "baseport" when starting a local server...
#
# File d:\Main\00_Research\00_Python\01_AI-ME_Graduate\AI-ME-Practice\.venv\Lib\site-packages\h2o\backend\connection.py:406, in H2OConnection.open(server, url, ip, port, name, https, auth, verify_ssl_certificates, cacert, proxy, cookies, verbose, msgs, strict_version_check)
#     405 conn._timeout = 3.0
# --> 406 conn._cluster = conn._test_connection(retries, messages=msgs)
#     407 # If a server is unable to respond within 1s, it should be considered a bug. However we disable this
#     408 # setting for now, for no good reason other than to ignore all those bugs :(
#
# File d:\Main\00_Research\00_Python\01_AI-ME_Graduate\AI-ME-Practice\.venv\Lib\site-packages\h2o\backend\connection.py:713, in H2OConnection._test_connection(self, max_retries, messages)
#     712 else:
# --> 713     raise H2OConnectionError("Could not establish link to the H2O cloud %s after %d retries\n%s"
#     714                              % (self._base_url, max_retries, "\n".join(errors)))
#
# H2OConnectionError: Could not establish link to the H2O cloud http://localhost:54321 after 5 retries
# [58:58.32] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001FB4A7AB890>: Failed to establish a new connection: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다'))
# [59:02.56] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001FB4C0D7E10>: Failed to establish a new connection: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다'))
# [59:06.81] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001FB4C0DDD90>: Failed to establish a new connection: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다'))
# [59:11.10] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001FB4C0DFC50>: Failed to establish a new connection: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다'))
# [59:15.38] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001FB4C0F5D50>: Failed to establish a new connection: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다'))
#
# During handling of the above exception, another exception occurred:
#
# H2OStartupError                           Traceback (most recent call last)
# Cell In[16], line 9
#       6 from sklearn.metrics import accuracy_score, classification_report
#       8 # Start/attach to an H2O cluster
# ----> 9 h2o.init(max_mem_size='2G')
#      11 # 2) Prepare frames
#      12 train_hf = h2o.H2OFrame(data_train)
#
# File d:\Main\00_Research\00_Python\01_AI-ME_Graduate\AI-ME-Practice\.venv\Lib\site-packages\h2o\h2o.py:287, in init(url, ip, port, name, https, cacert, insecure, username, password, cookies, proxy, start_h2o, nthreads, ice_root, log_dir, log_level, max_log_file_size, enable_assertions, max_mem_size, min_mem_size, strict_version_check, ignore_config, extra_classpath, jvm_custom_args, bind_to_localhost, verbose, **kwargs)
#     283     if https:
#     284         raise H2OConnectionError('Starting local server is not available with https enabled. You may start local'
#     285                                  ' instance of H2O with https manually '
#     286                                  '(https://docs.h2o.ai/h2o/latest-stable/h2o-docs/welcome.html#new-user-quick-start).')
# --> 287     hs = H2OLocalServer.start(nthreads=nthreads, enable_assertions=enable_assertions, max_mem_size=mmax,
#     288                               min_mem_size=mmin, ice_root=ice_root, log_dir=log_dir, log_level=log_level,
#     289                               max_log_file_size=max_log_file_size, port=port, name=name,
#     290                               extra_classpath=extra_classpath, jvm_custom_args=jvm_custom_args,
#     291                               bind_to_localhost=bind_to_localhost,verbose=verbose)
#     292     h2oconn = H2OConnection.open(server=hs, https=https, verify_ssl_certificates=verify_ssl_certificates,
#     293                                  cacert=cacert, auth=auth, proxy=proxy, cookies=cookies, verbose=verbose,
#     294                                  strict_version_check=svc)
#     295 h2oconn.cluster.timezone = "UTC"
#
# File d:\Main\00_Research\00_Python\01_AI-ME_Graduate\AI-ME-Practice\.venv\Lib\site-packages\h2o\backend\server.py:139, in H2OLocalServer.start(jar_path, nthreads, enable_assertions, max_mem_size, min_mem_size, ice_root, log_dir, log_level, max_log_file_size, port, name, extra_classpath, verbose, jvm_custom_args, bind_to_localhost)
#     136     hs._tempdir = hs._ice_root
#     138 if verbose: print("Attempting to start a local H2O server...")
# --> 139 hs._launch_server(port=port, baseport=baseport, nthreads=int(nthreads), ea=enable_assertions,
#     140                   mmax=max_mem_size, mmin=min_mem_size, jvm_custom_args=jvm_custom_args,
#     141                   bind_to_localhost=bind_to_localhost, log_dir=log_dir, log_level=log_level, max_log_file_size=max_log_file_size)
#     142 if verbose: print("  Server is running at %s://%s:%d" % (hs.scheme, hs.ip, hs.port))
#     143 atexit.register(lambda: hs.shutdown())
#
# File d:\Main\00_Research\00_Python\01_AI-ME_Graduate\AI-ME-Practice\.venv\Lib\site-packages\h2o\backend\server.py:271, in H2OLocalServer._launch_server(self, port, baseport, mmax, mmin, ea, nthreads, jvm_custom_args, bind_to_localhost, log_dir, log_level, max_log_file_size)
#     268 self._ip = "127.0.0.1"
#     270 # Find Java and check version. (Note that subprocess.check_output returns the output as a bytes object)
# --> 271 java = self._find_java()
#     272 self._check_java(java, self._verbose)
#     274 if self._verbose:
#
# File d:\Main\00_Research\00_Python\01_AI-ME_Graduate\AI-ME-Practice\.venv\Lib\site-packages\h2o\backend\server.py:453, in H2OLocalServer._find_java()
#     450                 return os.path.join(dirpath, java)
#     452 # not found...
# --> 453 raise H2OStartupError("Cannot find Java. Please install the latest JRE from\n"
#     454                       "http://docs.h2o.ai/h2o/latest-stable/h2o-docs/welcome.html#java-requirements")
#
# H2OStartupError: Cannot find Java. Please install the latest JRE from
# http://docs.h2o.ai/h2o/latest-stable/h2o-docs/welcome.html#java-requirements
